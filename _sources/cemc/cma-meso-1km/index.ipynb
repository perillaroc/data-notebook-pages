# %% [markdown]
# # CMA-MESO 1KM

# %% [markdown]
# CMA-MESO 基础 GRIB2 数据文件有 402 个要素场。

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso_grib2_orig_file_path = get_data_file("cma-meso-1km")
meso_grib2_orig_file_path

# %% [markdown]
# ## 要素列表
#
# 使用 ecCodes 打印 CMA-GFS 基础 GRIB2 数据的要素列表。

# %%
from IPython.utils.capture import capture_output

with capture_output() as captured:
    # !grib_ls -P count "{meso_grib2_orig_file_path}" 2>/dev/null

print(captured.stdout)
