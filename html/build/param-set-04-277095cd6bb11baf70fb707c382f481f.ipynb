# %% [markdown]
# # TYM要素清单：336-371

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(

# %%
from data_notebook.data import get_data_file

tym_grib2_orig_file_path = get_data_file("cma-tym")
tym_grib2_orig_file_path
# Out:
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-tym/grib2/orig/Z_NAFP_C_BABJ_20260811000000_P_NWPC-GRAPES-TYM-ACWP-02400.grib2')

# %% [markdown]
# ## 土壤温湿度

# %% [markdown]
# ### 层次
#
# 4 层列表（深度，厘米）：
#
# - 0-10cm
# - 10-30cm
# - 30-60cm
# - 60-100cm

# %% [markdown]
# ### 0-10厘米土壤温度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 0-10厘米土壤温度 | st(0-10) | TMP | t | (0, 0, 0) | depthBelowLandLayer | 0, 0.1 | 336 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="TMP",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="t",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="st(0-10)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %% [markdown]
# ### 土壤温度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 土壤温度 | st | TMP | t | (0, 0, 0) | depthBelowLandLayer | 0.1, 0.3 | 337 |
# | 土壤温度 | st | TMP | t | (0, 0, 0) | depthBelowLandLayer | 0.3, 0.6 | 338 |
# | 土壤温度 | st | TMP | t | (0, 0, 0) | depthBelowLandLayer | 0.6, 1 | 339 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="TMP",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.1,
        "second_level": 0.3,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 337

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="t",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.3,
        "second_level": 0.6,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 338

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="st",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1.0,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 339

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1.0,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 339

# %% [markdown]
# ### 0-10厘米土壤湿度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 0-10厘米土壤湿度 | sw(0-10) | SPFH | q | (0, 1, 0) | depthBelowLandLayer | 0, 0.1 | 340 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="SPFH",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 340

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="q",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 340

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="sw(0-10)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 340

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 340

# %% [markdown]
# ### 土壤湿度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 土壤湿度 | sw | SPFH | q | (0, 1, 0) | depthBelowLandLayer | 0.1, 0.3 | 341 |
# | 土壤湿度 | sw | SPFH | q | (0, 1, 0) | depthBelowLandLayer | 0.3, 0.6 | 342 |
# | 土壤湿度 | sw | SPFH | q | (0, 1, 0) | depthBelowLandLayer | 0.6, 1 | 343 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="SPFH",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.1,
        "second_level": 0.3,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 341

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="q",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.3,
        "second_level": 0.6,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 342

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="sw",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1.0,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 343

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1.0,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 343

# %% [markdown]
# ## 等压面：相对湿度

# %% [markdown]
# ### 层次
#
# 26 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100
# - 70
# - 50
# - 30
# - 20
# - 10

# %% [markdown]
# ### 相对湿度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 相对湿度 | rh | RH | r | (0, 1, 1) | pl | 26层 | 344-369 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="RH",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 344

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="r",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 352

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="rh",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 361

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 369

# %% [markdown]
# ## 近地面湿度与露点

# %% [markdown]
# ### 2米相对湿度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 2米相对湿度 | rh2m | RH | 2r | (0, 1, 1) | heightAboveGround | 2 | 370 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="RH",
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 370

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="2r",
    lazy=True
)
assert field.attrs["GRIB_count"] == 370

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="rh2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 370

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 370

# %% [markdown]
# ### 2米露点温度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 2米露点温度 | td2m | DPT | 2d | (0, 0, 6) | heightAboveGround | 2 | 371 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="DPT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 371

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="2d",
    lazy=True
)
assert field.attrs["GRIB_count"] == 371

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="td2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 371

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 6},
    lazy=True
)
assert field.attrs["GRIB_count"] == 371
