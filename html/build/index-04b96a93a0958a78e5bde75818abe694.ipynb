# %% [markdown]
# # CMA-TYM

# %% [markdown]
# CMA-TYM 基础 GRIB2 数据文件有 479 个要素场。
#
# 所有要素均为确定性预报（fc）。

# %%
import pandas as pd

# %%
from data_notebook.data import get_data_file

tym_grib2_orig_file_path = get_data_file("cma-tym")
tym_grib2_orig_file_path
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-tym/grib2/orig/Z_NAFP_C_BABJ_20260811000000_P_NWPC-GRAPES-TYM-ACWP-02400.grib2')

# %% [markdown]
# ## 要素列表
#
# 使用 reki 识别全部 GRIB2 消息头中的要素，并结合内置要素注册表生成要素列表。

# %%
from IPython.display import display
from data_notebook import get_grib2_inventory

inventory = get_grib2_inventory(tym_grib2_orig_file_path)
with pd.option_context("display.max_rows", None):
    display(inventory)
# Out:
#       序号          要素名 wgrib2  eccodes      GRIB key                  单位  \
# 0      1        rainc  ACPCP    acpcp    (0, 1, 10)                  mm
# 1      2       rainnc  NCPCP    ncpcp     (0, 1, 9)                  mm
# 2      3         rain   APCP  unknown     (0, 1, 8)                  mm
# 3      4           sf  ASNOW  unknown    (0, 1, 29)                   m
# 4      5           ts    TMP        t     (0, 0, 0)                   K
# 5      6          glw  NLWRF      str     (0, 5, 5)                w/m2
# 6      7          gsw  NSWRF      ssr     (0, 4, 9)                w/m2
# 7      8         sshf  HFLUX    hflux    (2, 0, 24)               ws/m2
# 8      9       qfxsfc    NaN  unknown   (0, 1, 229)           kg/(m2.s)
# 9     10           zs    HGT     orog     (0, 3, 5)                 Gpm
# 10    11          q2m   SPFH      2sh     (0, 1, 0)               kg/kg
# 11    12          t2m    TMP       2t     (0, 0, 0)                   K
# 12    13         u10m   UGRD      10u     (0, 2, 2)                 m/s
# 13    14         v10m   VGRD      10v     (0, 2, 3)                 m/s
# 14    15          tcc   TCDC      tcc     (0, 6, 1)                   %
# 15    16          lcc   LCDC      lcc     (0, 6, 3)                   %
# 16    17         cdbz     CR  unknown  (0, 16, 224)                 dbz
# 17    18       wmax#1   DZDT       wz     (0, 2, 9)                 m/s
# 18    19    u10mmax#1   UGRD      10u     (0, 2, 2)                 m/s
# 19    20    v10mmax#1   VGRD      10v     (0, 2, 3)                 m/s
# 20    21        uhmax   UPHL  unknown    (0, 7, 15)               m2/s2
# 21    22           ps   PRES       sp     (0, 3, 0)                  Pa
# 22    23          psl  PRMSL    prmsl     (0, 3, 1)                  Pa
# 23    24            h    HGT       gh     (0, 3, 5)                 Gpm
# 24    25            h    HGT       gh     (0, 3, 5)                 Gpm
# 25    26            h    HGT       gh     (0, 3, 5)                 Gpm
# 26    27            h    HGT       gh     (0, 3, 5)                 Gpm
# 27    28            h    HGT       gh     (0, 3, 5)                 Gpm
# 28    29            h    HGT       gh     (0, 3, 5)                 Gpm
# 29    30            h    HGT       gh     (0, 3, 5)                 Gpm
# 30    31            h    HGT       gh     (0, 3, 5)                 Gpm
# 31    32            h    HGT       gh     (0, 3, 5)                 Gpm
# 32    33            h    HGT       gh     (0, 3, 5)                 Gpm
# 33    34            h    HGT       gh     (0, 3, 5)                 Gpm
# 34    35            h    HGT       gh     (0, 3, 5)                 Gpm
# 35    36            h    HGT       gh     (0, 3, 5)                 Gpm
# 36    37            h    HGT       gh     (0, 3, 5)                 Gpm
# 37    38            h    HGT       gh     (0, 3, 5)                 Gpm
# 38    39            h    HGT       gh     (0, 3, 5)                 Gpm
# 39    40            h    HGT       gh     (0, 3, 5)                 Gpm
# 40    41            h    HGT       gh     (0, 3, 5)                 Gpm
# 41    42            h    HGT       gh     (0, 3, 5)                 Gpm
# 42    43            h    HGT       gh     (0, 3, 5)                 Gpm
# 43    44            h    HGT       gh     (0, 3, 5)                 Gpm
# 44    45            h    HGT       gh     (0, 3, 5)                 Gpm
# 45    46            h    HGT       gh     (0, 3, 5)                 Gpm
# 46    47            h    HGT       gh     (0, 3, 5)                 Gpm
# 47    48            h    HGT       gh     (0, 3, 5)                 Gpm
# 48    49            h    HGT       gh     (0, 3, 5)                 Gpm
# 49    50            t    TMP        t     (0, 0, 0)                   K
# 50    51            t    TMP        t     (0, 0, 0)                   K
# 51    52            t    TMP        t     (0, 0, 0)                   K
# 52    53            t    TMP        t     (0, 0, 0)                   K
# 53    54            t    TMP        t     (0, 0, 0)                   K
# 54    55            t    TMP        t     (0, 0, 0)                   K
# 55    56            t    TMP        t     (0, 0, 0)                   K
# 56    57            t    TMP        t     (0, 0, 0)                   K
# 57    58            t    TMP        t     (0, 0, 0)                   K
# 58    59            t    TMP        t     (0, 0, 0)                   K
# 59    60            t    TMP        t     (0, 0, 0)                   K
# 60    61            t    TMP        t     (0, 0, 0)                   K
# 61    62            t    TMP        t     (0, 0, 0)                   K
# 62    63            t    TMP        t     (0, 0, 0)                   K
# 63    64            t    TMP        t     (0, 0, 0)                   K
# 64    65            t    TMP        t     (0, 0, 0)                   K
# 65    66            t    TMP        t     (0, 0, 0)                   K
# 66    67            t    TMP        t     (0, 0, 0)                   K
# 67    68            t    TMP        t     (0, 0, 0)                   K
# 68    69            t    TMP        t     (0, 0, 0)                   K
# 69    70            t    TMP        t     (0, 0, 0)                   K
# 70    71            t    TMP        t     (0, 0, 0)                   K
# 71    72            t    TMP        t     (0, 0, 0)                   K
# 72    73            t    TMP        t     (0, 0, 0)                   K
# 73    74            t    TMP        t     (0, 0, 0)                   K
# 74    75            t    TMP        t     (0, 0, 0)                   K
# 75    76            u   UGRD        u     (0, 2, 2)                 m/s
# 76    77            u   UGRD        u     (0, 2, 2)                 m/s
# 77    78            u   UGRD        u     (0, 2, 2)                 m/s
# 78    79            u   UGRD        u     (0, 2, 2)                 m/s
# 79    80            u   UGRD        u     (0, 2, 2)                 m/s
# 80    81            u   UGRD        u     (0, 2, 2)                 m/s
# 81    82            u   UGRD        u     (0, 2, 2)                 m/s
# 82    83            u   UGRD        u     (0, 2, 2)                 m/s
# 83    84            u   UGRD        u     (0, 2, 2)                 m/s
# 84    85            u   UGRD        u     (0, 2, 2)                 m/s
# 85    86            u   UGRD        u     (0, 2, 2)                 m/s
# 86    87            u   UGRD        u     (0, 2, 2)                 m/s
# 87    88            u   UGRD        u     (0, 2, 2)                 m/s
# 88    89            u   UGRD        u     (0, 2, 2)                 m/s
# 89    90            u   UGRD        u     (0, 2, 2)                 m/s
# 90    91            u   UGRD        u     (0, 2, 2)                 m/s
# 91    92            u   UGRD        u     (0, 2, 2)                 m/s
# 92    93            u   UGRD        u     (0, 2, 2)                 m/s
# 93    94            u   UGRD        u     (0, 2, 2)                 m/s
# 94    95            u   UGRD        u     (0, 2, 2)                 m/s
# 95    96            u   UGRD        u     (0, 2, 2)                 m/s
# 96    97            u   UGRD        u     (0, 2, 2)                 m/s
# 97    98            u   UGRD        u     (0, 2, 2)                 m/s
# 98    99            u   UGRD        u     (0, 2, 2)                 m/s
# 99   100            u   UGRD        u     (0, 2, 2)                 m/s
# 100  101            u   UGRD        u     (0, 2, 2)                 m/s
# 101  102            v   VGRD        v     (0, 2, 3)                 m/s
# 102  103            v   VGRD        v     (0, 2, 3)                 m/s
# 103  104            v   VGRD        v     (0, 2, 3)                 m/s
# 104  105            v   VGRD        v     (0, 2, 3)                 m/s
# 105  106            v   VGRD        v     (0, 2, 3)                 m/s
# 106  107            v   VGRD        v     (0, 2, 3)                 m/s
# 107  108            v   VGRD        v     (0, 2, 3)                 m/s
# 108  109            v   VGRD        v     (0, 2, 3)                 m/s
# 109  110            v   VGRD        v     (0, 2, 3)                 m/s
# 110  111            v   VGRD        v     (0, 2, 3)                 m/s
# 111  112            v   VGRD        v     (0, 2, 3)                 m/s
# 112  113            v   VGRD        v     (0, 2, 3)                 m/s
# 113  114            v   VGRD        v     (0, 2, 3)                 m/s
# 114  115            v   VGRD        v     (0, 2, 3)                 m/s
# 115  116            v   VGRD        v     (0, 2, 3)                 m/s
# 116  117            v   VGRD        v     (0, 2, 3)                 m/s
# 117  118            v   VGRD        v     (0, 2, 3)                 m/s
# 118  119            v   VGRD        v     (0, 2, 3)                 m/s
# 119  120            v   VGRD        v     (0, 2, 3)                 m/s
# 120  121            v   VGRD        v     (0, 2, 3)                 m/s
# 121  122            v   VGRD        v     (0, 2, 3)                 m/s
# 122  123            v   VGRD        v     (0, 2, 3)                 m/s
# 123  124            v   VGRD        v     (0, 2, 3)                 m/s
# 124  125            v   VGRD        v     (0, 2, 3)                 m/s
# 125  126            v   VGRD        v     (0, 2, 3)                 m/s
# 126  127            v   VGRD        v     (0, 2, 3)                 m/s
# 127  128            w   DZDT       wz     (0, 2, 9)                 m/s
# 128  129            w   DZDT       wz     (0, 2, 9)                 m/s
# 129  130            w   DZDT       wz     (0, 2, 9)                 m/s
# 130  131            w   DZDT       wz     (0, 2, 9)                 m/s
# 131  132            w   DZDT       wz     (0, 2, 9)                 m/s
# 132  133            w   DZDT       wz     (0, 2, 9)                 m/s
# 133  134            w   DZDT       wz     (0, 2, 9)                 m/s
# 134  135            w   DZDT       wz     (0, 2, 9)                 m/s
# 135  136            w   DZDT       wz     (0, 2, 9)                 m/s
# 136  137            w   DZDT       wz     (0, 2, 9)                 m/s
# 137  138            w   DZDT       wz     (0, 2, 9)                 m/s
# 138  139            w   DZDT       wz     (0, 2, 9)                 m/s
# 139  140            w   DZDT       wz     (0, 2, 9)                 m/s
# 140  141            w   DZDT       wz     (0, 2, 9)                 m/s
# 141  142            w   DZDT       wz     (0, 2, 9)                 m/s
# 142  143            w   DZDT       wz     (0, 2, 9)                 m/s
# 143  144            w   DZDT       wz     (0, 2, 9)                 m/s
# 144  145            w   DZDT       wz     (0, 2, 9)                 m/s
# 145  146            w   DZDT       wz     (0, 2, 9)                 m/s
# 146  147            w   DZDT       wz     (0, 2, 9)                 m/s
# 147  148            w   DZDT       wz     (0, 2, 9)                 m/s
# 148  149            w   DZDT       wz     (0, 2, 9)                 m/s
# 149  150            w   DZDT       wz     (0, 2, 9)                 m/s
# 150  151            w   DZDT       wz     (0, 2, 9)                 m/s
# 151  152            w   DZDT       wz     (0, 2, 9)                 m/s
# 152  153            w   DZDT       wz     (0, 2, 9)                 m/s
# 153  154            q   SPFH        q     (0, 1, 0)               kg/kg
# 154  155            q   SPFH        q     (0, 1, 0)               kg/kg
# 155  156            q   SPFH        q     (0, 1, 0)               kg/kg
# 156  157            q   SPFH        q     (0, 1, 0)               kg/kg
# 157  158            q   SPFH        q     (0, 1, 0)               kg/kg
# 158  159            q   SPFH        q     (0, 1, 0)               kg/kg
# 159  160            q   SPFH        q     (0, 1, 0)               kg/kg
# 160  161            q   SPFH        q     (0, 1, 0)               kg/kg
# 161  162            q   SPFH        q     (0, 1, 0)               kg/kg
# 162  163            q   SPFH        q     (0, 1, 0)               kg/kg
# 163  164            q   SPFH        q     (0, 1, 0)               kg/kg
# 164  165            q   SPFH        q     (0, 1, 0)               kg/kg
# 165  166            q   SPFH        q     (0, 1, 0)               kg/kg
# 166  167            q   SPFH        q     (0, 1, 0)               kg/kg
# 167  168            q   SPFH        q     (0, 1, 0)               kg/kg
# 168  169            q   SPFH        q     (0, 1, 0)               kg/kg
# 169  170            q   SPFH        q     (0, 1, 0)               kg/kg
# 170  171            q   SPFH        q     (0, 1, 0)               kg/kg
# 171  172            q   SPFH        q     (0, 1, 0)               kg/kg
# 172  173            q   SPFH        q     (0, 1, 0)               kg/kg
# 173  174            q   SPFH        q     (0, 1, 0)               kg/kg
# 174  175            q   SPFH        q     (0, 1, 0)               kg/kg
# 175  176            q   SPFH        q     (0, 1, 0)               kg/kg
# 176  177            q   SPFH        q     (0, 1, 0)               kg/kg
# 177  178            q   SPFH        q     (0, 1, 0)               kg/kg
# 178  179            q   SPFH        q     (0, 1, 0)               kg/kg
# 179  180           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 180  181           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 181  182           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 182  183           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 183  184           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 184  185           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 185  186           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 186  187           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 187  188           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 188  189           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 189  190           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 190  191           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 191  192           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 192  193           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 193  194           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 194  195           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 195  196           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 196  197           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 197  198           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 198  199           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 199  200           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 200  201           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 201  202           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 202  203           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 203  204           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 204  205           qc   CLMR    clwmr    (0, 1, 22)               kg/kg
# 205  206           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 206  207           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 207  208           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 208  209           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 209  210           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 210  211           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 211  212           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 212  213           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 213  214           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 214  215           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 215  216           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 216  217           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 217  218           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 218  219           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 219  220           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 220  221           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 221  222           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 222  223           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 223  224           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 224  225           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 225  226           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 226  227           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 227  228           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 228  229           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 229  230           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 230  231           qr   RWMR     rwmr    (0, 1, 24)               kg/kg
# 231  232           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 232  233           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 233  234           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 234  235           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 235  236           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 236  237           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 237  238           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 238  239           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 239  240           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 240  241           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 241  242           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 242  243           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 243  244           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 244  245           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 245  246           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 246  247           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 247  248           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 248  249           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 249  250           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 250  251           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 251  252           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 252  253           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 253  254           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 254  255           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 255  256           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 256  257           qi   ICMR     icmr    (0, 1, 23)               kg/kg
# 257  258           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 258  259           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 259  260           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 260  261           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 261  262           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 262  263           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 263  264           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 264  265           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 265  266           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 266  267           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 267  268           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 268  269           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 269  270           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 270  271           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 271  272           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 272  273           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 273  274           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 274  275           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 275  276           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 276  277           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 277  278           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 278  279           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 279  280           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 280  281           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 281  282           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 282  283           qs   SNMR     snmr    (0, 1, 25)               kg/kg
# 283  284      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 284  285      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 285  286      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 286  287      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 287  288      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 288  289      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 289  290      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 290  291      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 291  292      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 292  293      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 293  294      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 294  295      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 295  296      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 296  297      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 297  298      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 298  299      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 299  300      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 300  301      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 301  302      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 302  303      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 303  304      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 304  305      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 305  306      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 306  307      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 307  308      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 308  309      graupel   GRLE     grle    (0, 1, 32)               kg/kg
# 309  310           cc   CDCC      ccl    (0, 6, 22)                   %
# 310  311           cc   CDCC      ccl    (0, 6, 22)                   %
# 311  312           cc   CDCC      ccl    (0, 6, 22)                   %
# 312  313           cc   CDCC      ccl    (0, 6, 22)                   %
# 313  314           cc   CDCC      ccl    (0, 6, 22)                   %
# 314  315           cc   CDCC      ccl    (0, 6, 22)                   %
# 315  316           cc   CDCC      ccl    (0, 6, 22)                   %
# 316  317           cc   CDCC      ccl    (0, 6, 22)                   %
# 317  318           cc   CDCC      ccl    (0, 6, 22)                   %
# 318  319           cc   CDCC      ccl    (0, 6, 22)                   %
# 319  320           cc   CDCC      ccl    (0, 6, 22)                   %
# 320  321           cc   CDCC      ccl    (0, 6, 22)                   %
# 321  322           cc   CDCC      ccl    (0, 6, 22)                   %
# 322  323           cc   CDCC      ccl    (0, 6, 22)                   %
# 323  324           cc   CDCC      ccl    (0, 6, 22)                   %
# 324  325           cc   CDCC      ccl    (0, 6, 22)                   %
# 325  326           cc   CDCC      ccl    (0, 6, 22)                   %
# 326  327           cc   CDCC      ccl    (0, 6, 22)                   %
# 327  328           cc   CDCC      ccl    (0, 6, 22)                   %
# 328  329           cc   CDCC      ccl    (0, 6, 22)                   %
# 329  330           cc   CDCC      ccl    (0, 6, 22)                   %
# 330  331           cc   CDCC      ccl    (0, 6, 22)                   %
# 331  332           cc   CDCC      ccl    (0, 6, 22)                   %
# 332  333           cc   CDCC      ccl    (0, 6, 22)                   %
# 333  334           cc   CDCC      ccl    (0, 6, 22)                   %
# 334  335           cc   CDCC      ccl    (0, 6, 22)                   %
# 335  336     st(0-10)    TMP        t     (0, 0, 0)                   K
# 336  337           st    TMP        t     (0, 0, 0)                   K
# 337  338           st    TMP        t     (0, 0, 0)                   K
# 338  339           st    TMP        t     (0, 0, 0)                   K
# 339  340     sw(0-10)   SPFH        q     (0, 1, 0)               kg/kg
# 340  341           sw   SPFH        q     (0, 1, 0)               kg/kg
# 341  342           sw   SPFH        q     (0, 1, 0)               kg/kg
# 342  343           sw   SPFH        q     (0, 1, 0)               kg/kg
# 343  344           rh     RH        r     (0, 1, 1)                   %
# 344  345           rh     RH        r     (0, 1, 1)                   %
# 345  346           rh     RH        r     (0, 1, 1)                   %
# 346  347           rh     RH        r     (0, 1, 1)                   %
# 347  348           rh     RH        r     (0, 1, 1)                   %
# 348  349           rh     RH        r     (0, 1, 1)                   %
# 349  350           rh     RH        r     (0, 1, 1)                   %
# 350  351           rh     RH        r     (0, 1, 1)                   %
# 351  352           rh     RH        r     (0, 1, 1)                   %
# 352  353           rh     RH        r     (0, 1, 1)                   %
# 353  354           rh     RH        r     (0, 1, 1)                   %
# 354  355           rh     RH        r     (0, 1, 1)                   %
# 355  356           rh     RH        r     (0, 1, 1)                   %
# 356  357           rh     RH        r     (0, 1, 1)                   %
# 357  358           rh     RH        r     (0, 1, 1)                   %
# 358  359           rh     RH        r     (0, 1, 1)                   %
# 359  360           rh     RH        r     (0, 1, 1)                   %
# 360  361           rh     RH        r     (0, 1, 1)                   %
# 361  362           rh     RH        r     (0, 1, 1)                   %
# 362  363           rh     RH        r     (0, 1, 1)                   %
# 363  364           rh     RH        r     (0, 1, 1)                   %
# 364  365           rh     RH        r     (0, 1, 1)                   %
# 365  366           rh     RH        r     (0, 1, 1)                   %
# 366  367           rh     RH        r     (0, 1, 1)                   %
# 367  368           rh     RH        r     (0, 1, 1)                   %
# 368  369           rh     RH        r     (0, 1, 1)                   %
# 369  370         rh2m     RH       2r     (0, 1, 1)                   %
# 370  371         td2m    DPT       2d     (0, 0, 6)                   K
# 371  372          div   RELD        d    (0, 2, 13)                 s-1
# 372  373          div   RELD        d    (0, 2, 13)                 s-1
# 373  374          div   RELD        d    (0, 2, 13)                 s-1
# 374  375          div   RELD        d    (0, 2, 13)                 s-1
# 375  376          div   RELD        d    (0, 2, 13)                 s-1
# 376  377          div   RELD        d    (0, 2, 13)                 s-1
# 377  378          div   RELD        d    (0, 2, 13)                 s-1
# 378  379          vor   RELV       vo    (0, 2, 12)                 s-1
# 379  380          vor   RELV       vo    (0, 2, 12)                 s-1
# 380  381          vor   RELV       vo    (0, 2, 12)                 s-1
# 381  382          vor   RELV       vo    (0, 2, 12)                 s-1
# 382  383          vor   RELV       vo    (0, 2, 12)                 s-1
# 383  384          vor   RELV       vo    (0, 2, 12)                 s-1
# 384  385          vor   RELV       vo    (0, 2, 12)                 s-1
# 385  386         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 386  387         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 387  388         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 388  389         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 389  390         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 390  391         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 391  392         tadv    NaN  unknown   (0, 0, 224)           1.e-6 k/s
# 392  393         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 393  394         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 394  395         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 395  396         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 396  397         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 397  398         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 398  399         qflx    NaN  unknown   (0, 1, 224)   1e-1.g/(cm.hpa.s)
# 399  400         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 400  401         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 401  402         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 402  403         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 403  404         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 404  405         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 405  406         qdiv   FRZR  unknown   (0, 1, 225)  1e-7.g/(cm2.hpa.s)
# 406  407           td    DPT      dpt     (0, 0, 6)                   K
# 407  408           td    DPT      dpt     (0, 0, 6)                   K
# 408  409           td    DPT      dpt     (0, 0, 6)                   K
# 409  410           td    DPT      dpt     (0, 0, 6)                   K
# 410  411           td    DPT      dpt     (0, 0, 6)                   K
# 411  412           td    DPT      dpt     (0, 0, 6)                   K
# 412  413           td    DPT      dpt     (0, 0, 6)                   K
# 413  414           td    DPT      dpt     (0, 0, 6)                   K
# 414  415           td    DPT      dpt     (0, 0, 6)                   K
# 415  416           td    DPT      dpt     (0, 0, 6)                   K
# 416  417           td    DPT      dpt     (0, 0, 6)                   K
# 417  418           td    DPT      dpt     (0, 0, 6)                   K
# 418  419           td    DPT      dpt     (0, 0, 6)                   K
# 419  420           td    DPT      dpt     (0, 0, 6)                   K
# 420  421           td    DPT      dpt     (0, 0, 6)                   K
# 421  422           td    DPT      dpt     (0, 0, 6)                   K
# 422  423           td    DPT      dpt     (0, 0, 6)                   K
# 423  424           td    DPT      dpt     (0, 0, 6)                   K
# 424  425           td    DPT      dpt     (0, 0, 6)                   K
# 425  426           td    DPT      dpt     (0, 0, 6)                   K
# 426  427           td    DPT      dpt     (0, 0, 6)                   K
# 427  428           td    DPT      dpt     (0, 0, 6)                   K
# 428  429           td    DPT      dpt     (0, 0, 6)                   K
# 429  430           td    DPT      dpt     (0, 0, 6)                   K
# 430  431           td    DPT      dpt     (0, 0, 6)                   K
# 431  432           td    DPT      dpt     (0, 0, 6)                   K
# 432  433          ttd   DEPR  unknown     (0, 0, 7)                   K
# 433  434          ttd   DEPR  unknown     (0, 0, 7)                   K
# 434  435          ttd   DEPR  unknown     (0, 0, 7)                   K
# 435  436          ttd   DEPR  unknown     (0, 0, 7)                   K
# 436  437          ttd   DEPR  unknown     (0, 0, 7)                   K
# 437  438          ttd   DEPR  unknown     (0, 0, 7)                   K
# 438  439          ttd   DEPR  unknown     (0, 0, 7)                   K
# 439  440      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 440  441      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 441  442      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 442  443      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 443  444      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 444  445      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 445  446      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 446  447      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 447  448      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 448  449      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 449  450      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 450  451      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 451  452      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 452  453      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 453  454      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 454  455      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 455  456      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 456  457      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 457  458      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 458  459      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 459  460      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 460  461      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 461  462      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 462  463      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 463  464      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 464  465      thetaSe   EPOT     papt     (0, 0, 3)                   K
# 465  466         kidx     KX       kx     (0, 7, 2)                   C
# 466  467         cape   CAPE  unknown     (0, 7, 6)                J/kg
# 467  468          cin    CIN  unknown     (0, 7, 7)                J/kg
# 468  469  shr(0-1000)   VWSH     vwsh    (0, 2, 25)                 s-1
# 469  470  shr(0-3000)   VWSH     vwsh    (0, 2, 25)                 s-1
# 470  471  shr(0-6000)   VWSH     vwsh    (0, 2, 25)                 s-1
# 471  472          bli    BLI      bli     (0, 7, 1)                   K
# 472  473         pwat   PWAT     pwat     (0, 1, 3)               kg/kg
# 473  474          vis    VIS      vis    (0, 19, 0)                   m
# 474  475         fogh    NaN  unknown  (0, 19, 224)                   m
# 475  476        fogod    NaN  unknown  (0, 19, 225)             unknown
# 476  477         gust   GUST    i10fg    (0, 2, 22)                 m/s
# 477  478          bti    NaN  unknown   (0, 4, 228)                   K
# 478  479          btv    NaN  unknown   (0, 4, 227)                   K
#
#                        层次类型     层次     统计类型     时效 数据类型        网格类型
# 0                   surface      0    accum   0-24   fc  regular_ll
# 1                   surface      0    accum   0-24   fc  regular_ll
# 2                   surface      0    accum   0-24   fc  regular_ll
# 3                   surface      0    accum   0-24   fc  regular_ll
# 4                   surface      0  instant     24   fc  regular_ll
# 5                   surface      0    accum   0-24   fc  regular_ll
# 6                   surface      0    accum   0-24   fc  regular_ll
# 7                   surface      0    accum   0-24   fc  regular_ll
# 8                   surface      0  instant     24   fc  regular_ll
# 9                   surface      0  instant     24   fc  regular_ll
# 10        heightAboveGround      2  instant     24   fc  regular_ll
# 11        heightAboveGround      2  instant     24   fc  regular_ll
# 12        heightAboveGround     10  instant     24   fc  regular_ll
# 13        heightAboveGround     10  instant     24   fc  regular_ll
# 14         entireAtmosphere      0  instant     24   fc  regular_ll
# 15         entireAtmosphere      0  instant     24   fc  regular_ll
# 16                  surface      0  instant     24   fc  regular_ll
# 17            isobaricInhPa   1000      max  23-24   fc  regular_ll
# 18        heightAboveGround     10      max  23-24   fc  regular_ll
# 19        heightAboveGround     10      max  23-24   fc  regular_ll
# 20   heightAboveGroundLayer  34464      max   0-24   fc  regular_ll
# 21                  surface      0  instant     24   fc  regular_ll
# 22                  meanSea      0  instant     24   fc  regular_ll
# 23            isobaricInhPa   1000  instant     24   fc  regular_ll
# 24            isobaricInhPa    975  instant     24   fc  regular_ll
# 25            isobaricInhPa    950  instant     24   fc  regular_ll
# 26            isobaricInhPa    925  instant     24   fc  regular_ll
# 27            isobaricInhPa    900  instant     24   fc  regular_ll
# 28            isobaricInhPa    850  instant     24   fc  regular_ll
# 29            isobaricInhPa    800  instant     24   fc  regular_ll
# 30            isobaricInhPa    750  instant     24   fc  regular_ll
# 31            isobaricInhPa    700  instant     24   fc  regular_ll
# 32            isobaricInhPa    650  instant     24   fc  regular_ll
# 33            isobaricInhPa    600  instant     24   fc  regular_ll
# 34            isobaricInhPa    550  instant     24   fc  regular_ll
# 35            isobaricInhPa    500  instant     24   fc  regular_ll
# 36            isobaricInhPa    450  instant     24   fc  regular_ll
# 37            isobaricInhPa    400  instant     24   fc  regular_ll
# 38            isobaricInhPa    350  instant     24   fc  regular_ll
# 39            isobaricInhPa    300  instant     24   fc  regular_ll
# 40            isobaricInhPa    250  instant     24   fc  regular_ll
# 41            isobaricInhPa    200  instant     24   fc  regular_ll
# 42            isobaricInhPa    150  instant     24   fc  regular_ll
# 43            isobaricInhPa    100  instant     24   fc  regular_ll
# 44            isobaricInhPa     70  instant     24   fc  regular_ll
# 45            isobaricInhPa     50  instant     24   fc  regular_ll
# 46            isobaricInhPa     30  instant     24   fc  regular_ll
# 47            isobaricInhPa     20  instant     24   fc  regular_ll
# 48            isobaricInhPa     10  instant     24   fc  regular_ll
# 49            isobaricInhPa   1000  instant     24   fc  regular_ll
# 50            isobaricInhPa    975  instant     24   fc  regular_ll
# 51            isobaricInhPa    950  instant     24   fc  regular_ll
# 52            isobaricInhPa    925  instant     24   fc  regular_ll
# 53            isobaricInhPa    900  instant     24   fc  regular_ll
# 54            isobaricInhPa    850  instant     24   fc  regular_ll
# 55            isobaricInhPa    800  instant     24   fc  regular_ll
# 56            isobaricInhPa    750  instant     24   fc  regular_ll
# 57            isobaricInhPa    700  instant     24   fc  regular_ll
# 58            isobaricInhPa    650  instant     24   fc  regular_ll
# 59            isobaricInhPa    600  instant     24   fc  regular_ll
# 60            isobaricInhPa    550  instant     24   fc  regular_ll
# 61            isobaricInhPa    500  instant     24   fc  regular_ll
# 62            isobaricInhPa    450  instant     24   fc  regular_ll
# 63            isobaricInhPa    400  instant     24   fc  regular_ll
# 64            isobaricInhPa    350  instant     24   fc  regular_ll
# 65            isobaricInhPa    300  instant     24   fc  regular_ll
# 66            isobaricInhPa    250  instant     24   fc  regular_ll
# 67            isobaricInhPa    200  instant     24   fc  regular_ll
# 68            isobaricInhPa    150  instant     24   fc  regular_ll
# 69            isobaricInhPa    100  instant     24   fc  regular_ll
# 70            isobaricInhPa     70  instant     24   fc  regular_ll
# 71            isobaricInhPa     50  instant     24   fc  regular_ll
# 72            isobaricInhPa     30  instant     24   fc  regular_ll
# 73            isobaricInhPa     20  instant     24   fc  regular_ll
# 74            isobaricInhPa     10  instant     24   fc  regular_ll
# 75            isobaricInhPa   1000  instant     24   fc  regular_ll
# 76            isobaricInhPa    975  instant     24   fc  regular_ll
# 77            isobaricInhPa    950  instant     24   fc  regular_ll
# 78            isobaricInhPa    925  instant     24   fc  regular_ll
# 79            isobaricInhPa    900  instant     24   fc  regular_ll
# 80            isobaricInhPa    850  instant     24   fc  regular_ll
# 81            isobaricInhPa    800  instant     24   fc  regular_ll
# 82            isobaricInhPa    750  instant     24   fc  regular_ll
# 83            isobaricInhPa    700  instant     24   fc  regular_ll
# 84            isobaricInhPa    650  instant     24   fc  regular_ll
# 85            isobaricInhPa    600  instant     24   fc  regular_ll
# 86            isobaricInhPa    550  instant     24   fc  regular_ll
# 87            isobaricInhPa    500  instant     24   fc  regular_ll
# 88            isobaricInhPa    450  instant     24   fc  regular_ll
# 89            isobaricInhPa    400  instant     24   fc  regular_ll
# 90            isobaricInhPa    350  instant     24   fc  regular_ll
# 91            isobaricInhPa    300  instant     24   fc  regular_ll
# 92            isobaricInhPa    250  instant     24   fc  regular_ll
# 93            isobaricInhPa    200  instant     24   fc  regular_ll
# 94            isobaricInhPa    150  instant     24   fc  regular_ll
# 95            isobaricInhPa    100  instant     24   fc  regular_ll
# 96            isobaricInhPa     70  instant     24   fc  regular_ll
# 97            isobaricInhPa     50  instant     24   fc  regular_ll
# 98            isobaricInhPa     30  instant     24   fc  regular_ll
# 99            isobaricInhPa     20  instant     24   fc  regular_ll
# 100           isobaricInhPa     10  instant     24   fc  regular_ll
# 101           isobaricInhPa   1000  instant     24   fc  regular_ll
# 102           isobaricInhPa    975  instant     24   fc  regular_ll
# 103           isobaricInhPa    950  instant     24   fc  regular_ll
# 104           isobaricInhPa    925  instant     24   fc  regular_ll
# 105           isobaricInhPa    900  instant     24   fc  regular_ll
# 106           isobaricInhPa    850  instant     24   fc  regular_ll
# 107           isobaricInhPa    800  instant     24   fc  regular_ll
# 108           isobaricInhPa    750  instant     24   fc  regular_ll
# 109           isobaricInhPa    700  instant     24   fc  regular_ll
# 110           isobaricInhPa    650  instant     24   fc  regular_ll
# 111           isobaricInhPa    600  instant     24   fc  regular_ll
# 112           isobaricInhPa    550  instant     24   fc  regular_ll
# 113           isobaricInhPa    500  instant     24   fc  regular_ll
# 114           isobaricInhPa    450  instant     24   fc  regular_ll
# 115           isobaricInhPa    400  instant     24   fc  regular_ll
# 116           isobaricInhPa    350  instant     24   fc  regular_ll
# 117           isobaricInhPa    300  instant     24   fc  regular_ll
# 118           isobaricInhPa    250  instant     24   fc  regular_ll
# 119           isobaricInhPa    200  instant     24   fc  regular_ll
# 120           isobaricInhPa    150  instant     24   fc  regular_ll
# 121           isobaricInhPa    100  instant     24   fc  regular_ll
# 122           isobaricInhPa     70  instant     24   fc  regular_ll
# 123           isobaricInhPa     50  instant     24   fc  regular_ll
# 124           isobaricInhPa     30  instant     24   fc  regular_ll
# 125           isobaricInhPa     20  instant     24   fc  regular_ll
# 126           isobaricInhPa     10  instant     24   fc  regular_ll
# 127           isobaricInhPa   1000  instant     24   fc  regular_ll
# 128           isobaricInhPa    975  instant     24   fc  regular_ll
# 129           isobaricInhPa    950  instant     24   fc  regular_ll
# 130           isobaricInhPa    925  instant     24   fc  regular_ll
# 131           isobaricInhPa    900  instant     24   fc  regular_ll
# 132           isobaricInhPa    850  instant     24   fc  regular_ll
# 133           isobaricInhPa    800  instant     24   fc  regular_ll
# 134           isobaricInhPa    750  instant     24   fc  regular_ll
# 135           isobaricInhPa    700  instant     24   fc  regular_ll
# 136           isobaricInhPa    650  instant     24   fc  regular_ll
# 137           isobaricInhPa    600  instant     24   fc  regular_ll
# 138           isobaricInhPa    550  instant     24   fc  regular_ll
# 139           isobaricInhPa    500  instant     24   fc  regular_ll
# 140           isobaricInhPa    450  instant     24   fc  regular_ll
# 141           isobaricInhPa    400  instant     24   fc  regular_ll
# 142           isobaricInhPa    350  instant     24   fc  regular_ll
# 143           isobaricInhPa    300  instant     24   fc  regular_ll
# 144           isobaricInhPa    250  instant     24   fc  regular_ll
# 145           isobaricInhPa    200  instant     24   fc  regular_ll
# 146           isobaricInhPa    150  instant     24   fc  regular_ll
# 147           isobaricInhPa    100  instant     24   fc  regular_ll
# 148           isobaricInhPa     70  instant     24   fc  regular_ll
# 149           isobaricInhPa     50  instant     24   fc  regular_ll
# 150           isobaricInhPa     30  instant     24   fc  regular_ll
# 151           isobaricInhPa     20  instant     24   fc  regular_ll
# 152           isobaricInhPa     10  instant     24   fc  regular_ll
# 153           isobaricInhPa   1000  instant     24   fc  regular_ll
# 154           isobaricInhPa    975  instant     24   fc  regular_ll
# 155           isobaricInhPa    950  instant     24   fc  regular_ll
# 156           isobaricInhPa    925  instant     24   fc  regular_ll
# 157           isobaricInhPa    900  instant     24   fc  regular_ll
# 158           isobaricInhPa    850  instant     24   fc  regular_ll
# 159           isobaricInhPa    800  instant     24   fc  regular_ll
# 160           isobaricInhPa    750  instant     24   fc  regular_ll
# 161           isobaricInhPa    700  instant     24   fc  regular_ll
# 162           isobaricInhPa    650  instant     24   fc  regular_ll
# 163           isobaricInhPa    600  instant     24   fc  regular_ll
# 164           isobaricInhPa    550  instant     24   fc  regular_ll
# 165           isobaricInhPa    500  instant     24   fc  regular_ll
# 166           isobaricInhPa    450  instant     24   fc  regular_ll
# 167           isobaricInhPa    400  instant     24   fc  regular_ll
# 168           isobaricInhPa    350  instant     24   fc  regular_ll
# 169           isobaricInhPa    300  instant     24   fc  regular_ll
# ...
# 251           isobaricInhPa    100  instant     24   fc  regular_ll
# 252           isobaricInhPa     70  instant     24   fc  regular_ll
# 253           isobaricInhPa     50  instant     24   fc  regular_ll
# 254           isobaricInhPa     30  instant     24   fc  regular_ll
# 255           isobaricInhPa     20  instant     24   fc  regular_ll
# 256           isobaricInhPa     10  instant     24   fc  regular_ll
# 257           isobaricInhPa   1000  instant     24   fc  regular_ll
# 258           isobaricInhPa    975  instant     24   fc  regular_ll
# 259           isobaricInhPa    950  instant     24   fc  regular_ll
# 260           isobaricInhPa    925  instant     24   fc  regular_ll
# 261           isobaricInhPa    900  instant     24   fc  regular_ll
# 262           isobaricInhPa    850  instant     24   fc  regular_ll
# 263           isobaricInhPa    800  instant     24   fc  regular_ll
# 264           isobaricInhPa    750  instant     24   fc  regular_ll
# 265           isobaricInhPa    700  instant     24   fc  regular_ll
# 266           isobaricInhPa    650  instant     24   fc  regular_ll
# 267           isobaricInhPa    600  instant     24   fc  regular_ll
# 268           isobaricInhPa    550  instant     24   fc  regular_ll
# 269           isobaricInhPa    500  instant     24   fc  regular_ll
# 270           isobaricInhPa    450  instant     24   fc  regular_ll
# 271           isobaricInhPa    400  instant     24   fc  regular_ll
# 272           isobaricInhPa    350  instant     24   fc  regular_ll
# 273           isobaricInhPa    300  instant     24   fc  regular_ll
# 274           isobaricInhPa    250  instant     24   fc  regular_ll
# 275           isobaricInhPa    200  instant     24   fc  regular_ll
# 276           isobaricInhPa    150  instant     24   fc  regular_ll
# 277           isobaricInhPa    100  instant     24   fc  regular_ll
# 278           isobaricInhPa     70  instant     24   fc  regular_ll
# 279           isobaricInhPa     50  instant     24   fc  regular_ll
# 280           isobaricInhPa     30  instant     24   fc  regular_ll
# 281           isobaricInhPa     20  instant     24   fc  regular_ll
# 282           isobaricInhPa     10  instant     24   fc  regular_ll
# 283           isobaricInhPa   1000  instant     24   fc  regular_ll
# 284           isobaricInhPa    975  instant     24   fc  regular_ll
# 285           isobaricInhPa    950  instant     24   fc  regular_ll
# 286           isobaricInhPa    925  instant     24   fc  regular_ll
# 287           isobaricInhPa    900  instant     24   fc  regular_ll
# 288           isobaricInhPa    850  instant     24   fc  regular_ll
# 289           isobaricInhPa    800  instant     24   fc  regular_ll
# 290           isobaricInhPa    750  instant     24   fc  regular_ll
# 291           isobaricInhPa    700  instant     24   fc  regular_ll
# 292           isobaricInhPa    650  instant     24   fc  regular_ll
# 293           isobaricInhPa    600  instant     24   fc  regular_ll
# 294           isobaricInhPa    550  instant     24   fc  regular_ll
# 295           isobaricInhPa    500  instant     24   fc  regular_ll
# 296           isobaricInhPa    450  instant     24   fc  regular_ll
# 297           isobaricInhPa    400  instant     24   fc  regular_ll
# 298           isobaricInhPa    350  instant     24   fc  regular_ll
# 299           isobaricInhPa    300  instant     24   fc  regular_ll
# 300           isobaricInhPa    250  instant     24   fc  regular_ll
# 301           isobaricInhPa    200  instant     24   fc  regular_ll
# 302           isobaricInhPa    150  instant     24   fc  regular_ll
# 303           isobaricInhPa    100  instant     24   fc  regular_ll
# 304           isobaricInhPa     70  instant     24   fc  regular_ll
# 305           isobaricInhPa     50  instant     24   fc  regular_ll
# 306           isobaricInhPa     30  instant     24   fc  regular_ll
# 307           isobaricInhPa     20  instant     24   fc  regular_ll
# 308           isobaricInhPa     10  instant     24   fc  regular_ll
# 309           isobaricInhPa   1000  instant     24   fc  regular_ll
# 310           isobaricInhPa    975  instant     24   fc  regular_ll
# 311           isobaricInhPa    950  instant     24   fc  regular_ll
# 312           isobaricInhPa    925  instant     24   fc  regular_ll
# 313           isobaricInhPa    900  instant     24   fc  regular_ll
# 314           isobaricInhPa    850  instant     24   fc  regular_ll
# 315           isobaricInhPa    800  instant     24   fc  regular_ll
# 316           isobaricInhPa    750  instant     24   fc  regular_ll
# 317           isobaricInhPa    700  instant     24   fc  regular_ll
# 318           isobaricInhPa    650  instant     24   fc  regular_ll
# 319           isobaricInhPa    600  instant     24   fc  regular_ll
# 320           isobaricInhPa    550  instant     24   fc  regular_ll
# 321           isobaricInhPa    500  instant     24   fc  regular_ll
# 322           isobaricInhPa    450  instant     24   fc  regular_ll
# 323           isobaricInhPa    400  instant     24   fc  regular_ll
# 324           isobaricInhPa    350  instant     24   fc  regular_ll
# 325           isobaricInhPa    300  instant     24   fc  regular_ll
# 326           isobaricInhPa    250  instant     24   fc  regular_ll
# 327           isobaricInhPa    200  instant     24   fc  regular_ll
# 328           isobaricInhPa    150  instant     24   fc  regular_ll
# 329           isobaricInhPa    100  instant     24   fc  regular_ll
# 330           isobaricInhPa     70  instant     24   fc  regular_ll
# 331           isobaricInhPa     50  instant     24   fc  regular_ll
# 332           isobaricInhPa     30  instant     24   fc  regular_ll
# 333           isobaricInhPa     20  instant     24   fc  regular_ll
# 334           isobaricInhPa     10  instant     24   fc  regular_ll
# 335     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 336     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 337     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 338     depthBelowLandLayer      1  instant     24   fc  regular_ll
# 339     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 340     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 341     depthBelowLandLayer      0  instant     24   fc  regular_ll
# 342     depthBelowLandLayer      1  instant     24   fc  regular_ll
# 343           isobaricInhPa   1000  instant     24   fc  regular_ll
# 344           isobaricInhPa    975  instant     24   fc  regular_ll
# 345           isobaricInhPa    950  instant     24   fc  regular_ll
# 346           isobaricInhPa    925  instant     24   fc  regular_ll
# 347           isobaricInhPa    900  instant     24   fc  regular_ll
# 348           isobaricInhPa    850  instant     24   fc  regular_ll
# 349           isobaricInhPa    800  instant     24   fc  regular_ll
# 350           isobaricInhPa    750  instant     24   fc  regular_ll
# 351           isobaricInhPa    700  instant     24   fc  regular_ll
# 352           isobaricInhPa    650  instant     24   fc  regular_ll
# 353           isobaricInhPa    600  instant     24   fc  regular_ll
# 354           isobaricInhPa    550  instant     24   fc  regular_ll
# 355           isobaricInhPa    500  instant     24   fc  regular_ll
# 356           isobaricInhPa    450  instant     24   fc  regular_ll
# 357           isobaricInhPa    400  instant     24   fc  regular_ll
# 358           isobaricInhPa    350  instant     24   fc  regular_ll
# 359           isobaricInhPa    300  instant     24   fc  regular_ll
# 360           isobaricInhPa    250  instant     24   fc  regular_ll
# 361           isobaricInhPa    200  instant     24   fc  regular_ll
# 362           isobaricInhPa    150  instant     24   fc  regular_ll
# 363           isobaricInhPa    100  instant     24   fc  regular_ll
# 364           isobaricInhPa     70  instant     24   fc  regular_ll
# 365           isobaricInhPa     50  instant     24   fc  regular_ll
# 366           isobaricInhPa     30  instant     24   fc  regular_ll
# 367           isobaricInhPa     20  instant     24   fc  regular_ll
# 368           isobaricInhPa     10  instant     24   fc  regular_ll
# 369       heightAboveGround      2  instant     24   fc  regular_ll
# 370       heightAboveGround      2  instant     24   fc  regular_ll
# 371           isobaricInhPa   1000  instant     24   fc  regular_ll
# 372           isobaricInhPa    925  instant     24   fc  regular_ll
# 373           isobaricInhPa    850  instant     24   fc  regular_ll
# 374           isobaricInhPa    700  instant     24   fc  regular_ll
# 375           isobaricInhPa    500  instant     24   fc  regular_ll
# 376           isobaricInhPa    200  instant     24   fc  regular_ll
# 377           isobaricInhPa    100  instant     24   fc  regular_ll
# 378           isobaricInhPa   1000  instant     24   fc  regular_ll
# 379           isobaricInhPa    925  instant     24   fc  regular_ll
# 380           isobaricInhPa    850  instant     24   fc  regular_ll
# 381           isobaricInhPa    700  instant     24   fc  regular_ll
# 382           isobaricInhPa    500  instant     24   fc  regular_ll
# 383           isobaricInhPa    200  instant     24   fc  regular_ll
# 384           isobaricInhPa    100  instant     24   fc  regular_ll
# 385           isobaricInhPa   1000  instant     24   fc  regular_ll
# 386           isobaricInhPa    925  instant     24   fc  regular_ll
# 387           isobaricInhPa    850  instant     24   fc  regular_ll
# 388           isobaricInhPa    700  instant     24   fc  regular_ll
# 389           isobaricInhPa    500  instant     24   fc  regular_ll
# 390           isobaricInhPa    200  instant     24   fc  regular_ll
# 391           isobaricInhPa    100  instant     24   fc  regular_ll
# 392           isobaricInhPa   1000  instant     24   fc  regular_ll
# 393           isobaricInhPa    925  instant     24   fc  regular_ll
# 394           isobaricInhPa    850  instant     24   fc  regular_ll
# 395           isobaricInhPa    700  instant     24   fc  regular_ll
# 396           isobaricInhPa    500  instant     24   fc  regular_ll
# 397           isobaricInhPa    200  instant     24   fc  regular_ll
# 398           isobaricInhPa    100  instant     24   fc  regular_ll
# 399           isobaricInhPa   1000  instant     24   fc  regular_ll
# 400           isobaricInhPa    925  instant     24   fc  regular_ll
# 401           isobaricInhPa    850  instant     24   fc  regular_ll
# 402           isobaricInhPa    700  instant     24   fc  regular_ll
# 403           isobaricInhPa    500  instant     24   fc  regular_ll
# 404           isobaricInhPa    200  instant     24   fc  regular_ll
# 405           isobaricInhPa    100  instant     24   fc  regular_ll
# 406           isobaricInhPa   1000  instant     24   fc  regular_ll
# 407           isobaricInhPa    975  instant     24   fc  regular_ll
# 408           isobaricInhPa    950  instant     24   fc  regular_ll
# 409           isobaricInhPa    925  instant     24   fc  regular_ll
# 410           isobaricInhPa    900  instant     24   fc  regular_ll
# 411           isobaricInhPa    850  instant     24   fc  regular_ll
# 412           isobaricInhPa    800  instant     24   fc  regular_ll
# 413           isobaricInhPa    750  instant     24   fc  regular_ll
# 414           isobaricInhPa    700  instant     24   fc  regular_ll
# 415           isobaricInhPa    650  instant     24   fc  regular_ll
# 416           isobaricInhPa    600  instant     24   fc  regular_ll
# 417           isobaricInhPa    550  instant     24   fc  regular_ll
# 418           isobaricInhPa    500  instant     24   fc  regular_ll
# 419           isobaricInhPa    450  instant     24   fc  regular_ll
# 420           isobaricInhPa    400  instant     24   fc  regular_ll
# 421           isobaricInhPa    350  instant     24   fc  regular_ll
# 422           isobaricInhPa    300  instant     24   fc  regular_ll
# 423           isobaricInhPa    250  instant     24   fc  regular_ll
# 424           isobaricInhPa    200  instant     24   fc  regular_ll
# 425           isobaricInhPa    150  instant     24   fc  regular_ll
# 426           isobaricInhPa    100  instant     24   fc  regular_ll
# 427           isobaricInhPa     70  instant     24   fc  regular_ll
# 428           isobaricInhPa     50  instant     24   fc  regular_ll
# 429           isobaricInhPa     30  instant     24   fc  regular_ll
# 430           isobaricInhPa     20  instant     24   fc  regular_ll
# 431           isobaricInhPa     10  instant     24   fc  regular_ll
# 432           isobaricInhPa   1000  instant     24   fc  regular_ll
# 433           isobaricInhPa    925  instant     24   fc  regular_ll
# 434           isobaricInhPa    850  instant     24   fc  regular_ll
# 435           isobaricInhPa    700  instant     24   fc  regular_ll
# 436           isobaricInhPa    500  instant     24   fc  regular_ll
# 437           isobaricInhPa    200  instant     24   fc  regular_ll
# 438           isobaricInhPa    100  instant     24   fc  regular_ll
# 439           isobaricInhPa   1000  instant     24   fc  regular_ll
# 440           isobaricInhPa    975  instant     24   fc  regular_ll
# 441           isobaricInhPa    950  instant     24   fc  regular_ll
# 442           isobaricInhPa    925  instant     24   fc  regular_ll
# 443           isobaricInhPa    900  instant     24   fc  regular_ll
# 444           isobaricInhPa    850  instant     24   fc  regular_ll
# 445           isobaricInhPa    800  instant     24   fc  regular_ll
# 446           isobaricInhPa    750  instant     24   fc  regular_ll
# 447           isobaricInhPa    700  instant     24   fc  regular_ll
# 448           isobaricInhPa    650  instant     24   fc  regular_ll
# 449           isobaricInhPa    600  instant     24   fc  regular_ll
# 450           isobaricInhPa    550  instant     24   fc  regular_ll
# 451           isobaricInhPa    500  instant     24   fc  regular_ll
# 452           isobaricInhPa    450  instant     24   fc  regular_ll
# 453           isobaricInhPa    400  instant     24   fc  regular_ll
# 454           isobaricInhPa    350  instant     24   fc  regular_ll
# 455           isobaricInhPa    300  instant     24   fc  regular_ll
# 456           isobaricInhPa    250  instant     24   fc  regular_ll
# 457           isobaricInhPa    200  instant     24   fc  regular_ll
# 458           isobaricInhPa    150  instant     24   fc  regular_ll
# 459           isobaricInhPa    100  instant     24   fc  regular_ll
# 460           isobaricInhPa     70  instant     24   fc  regular_ll
# 461           isobaricInhPa     50  instant     24   fc  regular_ll
# 462           isobaricInhPa     30  instant     24   fc  regular_ll
# 463           isobaricInhPa     20  instant     24   fc  regular_ll
# 464           isobaricInhPa     10  instant     24   fc  regular_ll
# 465                 meanSea      0  instant     24   fc  regular_ll
# 466                 surface      0  instant     24   fc  regular_ll
# 467                 surface      0  instant     24   fc  regular_ll
# 468  heightAboveGroundLayer   1000  instant     24   fc  regular_ll
# 469  heightAboveGroundLayer   3000  instant     24   fc  regular_ll
# 470  heightAboveGroundLayer   6000  instant     24   fc  regular_ll
# 471                 surface      0  instant     24   fc  regular_ll
# 472              atmosphere      0  instant     24   fc  regular_ll
# 473                 surface      0  instant     24   fc  regular_ll
# 474                 surface      0  instant     24   fc  regular_ll
# 475                 surface      0  instant     24   fc  regular_ll
# 476       heightAboveGround     10  instant     24   fc  regular_ll
# 477                 surface      0  instant     24   fc  regular_ll
# 478                 surface      0  instant     24   fc  regular_ll
