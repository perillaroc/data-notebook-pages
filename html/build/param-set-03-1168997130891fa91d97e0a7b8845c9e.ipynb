# %% [markdown]
# # TYM要素清单：180-335

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(

# %%
from data_notebook.data import get_data_file

tym_grib2_orig_file_path = get_data_file("cma-tym")
tym_grib2_orig_file_path
# Out:
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-tym/grib2/orig/Z_NAFP_C_BABJ_20260811000000_P_NWPC-GRAPES-TYM-ACWP-02400.grib2')

# %% [markdown]
# ## 等压面：水凝物与云量

# %% [markdown]
# ### 层次
#
# 26 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100
# - 70
# - 50
# - 30
# - 20
# - 10

# %% [markdown]
# ### 云水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 云水混合比 | qc | CLMR | clwmr | (0, 1, 22) | pl | 26层 | 180-205 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="CLMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 180

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="clwmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 188

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="qc",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 197

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 22},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 205

# %% [markdown]
# ### 雨水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 雨水混合比 | qr | RWMR | rwmr | (0, 1, 24) | pl | 26层 | 206-231 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="RWMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 206

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="rwmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 214

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="qr",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 223

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 24},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 231

# %% [markdown]
# ### 冰水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 冰水混合比 | qi | ICMR | icmr | (0, 1, 23) | pl | 26层 | 232-257 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="ICMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 232

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="icmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 240

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="qi",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 249

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 23},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 257

# %% [markdown]
# ### 雪水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 雪水混合比 | qs | SNMR | snmr | (0, 1, 25) | pl | 26层 | 258-283 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="SNMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 258

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="snmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 266

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="qs",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 275

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 25},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 283

# %% [markdown]
# ### 霰

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 霰 | graupel | GRLE | grle | (0, 1, 32) | pl | 26层 | 284-309 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="GRLE",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 284

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="grle",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 292

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="graupel",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 301

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 32},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 309

# %% [markdown]
# ### 云量

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 云量 | cc | CDCC | ccl | (0, 6, 22) | pl | 26层 | 310-335 |

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="CDCC",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 310

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="ccl",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 318

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter="cc",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 327

# %%
field = load_field_from_file(
    tym_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 22},
    level_type="pl",
    level=10,
    lazy=True
)
assert field.attrs["GRIB_count"] == 335
