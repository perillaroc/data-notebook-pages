# %% [markdown]
# # MESO-3KM要素清单：54-179

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 等压面：位势高度/温度/风/垂直速度/比湿

# %% [markdown]
# ### 层次
#
# 21 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100

# %% [markdown]
# ### 位势高度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 位势高度 | h | HGT | gh | (0, 3, 5) | pl | 21层 | 54-74 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HGT",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 54

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="gh",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 62

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="h",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 71

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 5},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 74

# %% [markdown]
# ### 温度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 温度 | t | TMP | t | (0, 0, 0) | pl | 21层 | 75-95 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TMP",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 75

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 83

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 92

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 95

# %% [markdown]
# ### 东西风

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 东西风 | u | UGRD | u | (0, 2, 2) | pl | 21层 | 96-116 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="UGRD",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 96

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 104

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 113

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 2},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 116

# %% [markdown]
# ### 南北风

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 南北风 | v | VGRD | v | (0, 2, 3) | pl | 21层 | 117-137 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="VGRD",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 117

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 125

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 134

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 3},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 137

# %% [markdown]
# ### 垂直速度

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 垂直速度 | w | DZDT | wz | (0, 2, 9) | pl | 21层 | 138-158 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DZDT",
    level_type="pl",
    level=975,
    lazy=True
)
assert field.attrs["GRIB_count"] == 139

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="wz",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 146

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="w",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 155

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 9},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 158

# %% [markdown]
# ### 比湿

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 比湿 | q | SPFH | q | (0, 1, 0) | pl | 21层 | 159-179 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SPFH",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 159

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="q",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 167

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="q",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 176

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 179
