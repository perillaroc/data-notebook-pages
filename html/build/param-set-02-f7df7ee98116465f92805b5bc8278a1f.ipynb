# %% [markdown]
# # REPS要素清单：11-58

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(

# %%
from data_notebook.data import get_data_file

reps_grib2_orig_file_path = get_data_file("cma-reps")
reps_grib2_orig_file_path
# Out:
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-reps/grib2/orig/Z_NAFP_C_BABJ_20260811060000_P_NWPC-GRAPES-REPS-CN-02400-m001.grib2')

# %% [markdown]
# ## 等压面要素

# %% [markdown]
# ### 层次
#
# 8 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 700
# - 500

# %% [markdown]
# ### 位势高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 11-18 | h | HGT | gh | (0, 3, 5) | Gpm | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="HGT",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 11

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="gh",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 13

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="h",
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 16

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 5},
    level_type="pl",
    level=500,
    lazy=True
)
assert field.attrs["GRIB_count"] == 18

# %% [markdown]
# ### 温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 19-26 | t | TMP | t | (0, 0, 0) | K | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="TMP",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 19

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="t",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 21

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 24

# %% [markdown]
# ### 东西风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 27-34 | u | UGRD | u | (0, 2, 2) | m/s | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="UGRD",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 27

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="u",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 29

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 2},
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 32

# %% [markdown]
# ### 南北风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 35-42 | v | VGRD | v | (0, 2, 3) | m/s | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VGRD",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 35

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="v",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 37

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 3},
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 40

# %% [markdown]
# ### 云水混合比

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 43-50 | qc | CLMR | clwmr | (0, 1, 22) | kg/kg | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="CLMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 43

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="clwmr",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 45

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="qc",
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 48

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 22},
    level_type="pl",
    level=500,
    lazy=True
)
assert field.attrs["GRIB_count"] == 50

# %% [markdown]
# ### 相对湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 51-58 | rh | RH | r | (0, 1, 1) | % | isobaricInhPa | 8层 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="RH",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 51

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="r",
    level_type="pl",
    level=950,
    lazy=True
)
assert field.attrs["GRIB_count"] == 53

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="rh",
    level_type="pl",
    level=850,
    lazy=True
)
assert field.attrs["GRIB_count"] == 56

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="pl",
    level=500,
    lazy=True
)
assert field.attrs["GRIB_count"] == 58
