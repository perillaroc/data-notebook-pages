# %% [markdown]
# # CMA-REPS

# %% [markdown]
# CMA-REPS 基础 GRIB2 数据文件有 71 个要素场。
#
# 本页文件为集合预报成员 1（文件名后缀 `-m001.grib2`）；所有要素均为集合扰动预报（pf）。

# %%
import pandas as pd

# %%
from data_notebook.data import get_data_file

reps_grib2_orig_file_path = get_data_file("cma-reps")
reps_grib2_orig_file_path
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-reps/grib2/orig/Z_NAFP_C_BABJ_20260811060000_P_NWPC-GRAPES-REPS-CN-02400-m001.grib2')

# %% [markdown]
# ## 要素列表
#
# 使用 reki 识别全部 GRIB2 消息头中的要素，并结合内置要素注册表生成要素列表。

# %%
from IPython.display import display
from data_notebook import get_grib2_inventory

inventory = get_grib2_inventory(reps_grib2_orig_file_path)
with pd.option_context("display.max_rows", None):
    display(inventory)
# Out:
#     序号          要素名 wgrib2  eccodes      GRIB key       单位  \
# 0    1        rainc  ACPCP    acpcp    (0, 1, 10)       mm
# 1    2         rain   APCP  unknown     (0, 1, 8)       mm
# 2    3           sf  ASNOW  unknown    (0, 1, 29)        m
# 3    4           ts    TMP        t     (0, 0, 0)        K
# 4    5          t2m    TMP       2t     (0, 0, 0)        K
# 5    6         u10m   UGRD      10u     (0, 2, 2)      m/s
# 6    7         v10m   VGRD      10v     (0, 2, 3)      m/s
# 7    8         cdbz     CR  unknown  (0, 16, 224)      dbz
# 8    9           sd   SNOD      sde    (0, 1, 11)        m
# 9   10          psl  PRMSL    prmsl     (0, 3, 1)       Pa
# 10  11            h    HGT       gh     (0, 3, 5)      Gpm
# 11  12            h    HGT       gh     (0, 3, 5)      Gpm
# 12  13            h    HGT       gh     (0, 3, 5)      Gpm
# 13  14            h    HGT       gh     (0, 3, 5)      Gpm
# 14  15            h    HGT       gh     (0, 3, 5)      Gpm
# 15  16            h    HGT       gh     (0, 3, 5)      Gpm
# 16  17            h    HGT       gh     (0, 3, 5)      Gpm
# 17  18            h    HGT       gh     (0, 3, 5)      Gpm
# 18  19            t    TMP        t     (0, 0, 0)        K
# 19  20            t    TMP        t     (0, 0, 0)        K
# 20  21            t    TMP        t     (0, 0, 0)        K
# 21  22            t    TMP        t     (0, 0, 0)        K
# 22  23            t    TMP        t     (0, 0, 0)        K
# 23  24            t    TMP        t     (0, 0, 0)        K
# 24  25            t    TMP        t     (0, 0, 0)        K
# 25  26            t    TMP        t     (0, 0, 0)        K
# 26  27            u   UGRD        u     (0, 2, 2)      m/s
# 27  28            u   UGRD        u     (0, 2, 2)      m/s
# 28  29            u   UGRD        u     (0, 2, 2)      m/s
# 29  30            u   UGRD        u     (0, 2, 2)      m/s
# 30  31            u   UGRD        u     (0, 2, 2)      m/s
# 31  32            u   UGRD        u     (0, 2, 2)      m/s
# 32  33            u   UGRD        u     (0, 2, 2)      m/s
# 33  34            u   UGRD        u     (0, 2, 2)      m/s
# 34  35            v   VGRD        v     (0, 2, 3)      m/s
# 35  36            v   VGRD        v     (0, 2, 3)      m/s
# 36  37            v   VGRD        v     (0, 2, 3)      m/s
# 37  38            v   VGRD        v     (0, 2, 3)      m/s
# 38  39            v   VGRD        v     (0, 2, 3)      m/s
# 39  40            v   VGRD        v     (0, 2, 3)      m/s
# 40  41            v   VGRD        v     (0, 2, 3)      m/s
# 41  42            v   VGRD        v     (0, 2, 3)      m/s
# 42  43           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 43  44           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 44  45           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 45  46           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 46  47           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 47  48           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 48  49           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 49  50           qc   CLMR    clwmr    (0, 1, 22)    kg/kg
# 50  51           rh     RH        r     (0, 1, 1)        %
# 51  52           rh     RH        r     (0, 1, 1)        %
# 52  53           rh     RH        r     (0, 1, 1)        %
# 53  54           rh     RH        r     (0, 1, 1)        %
# 54  55           rh     RH        r     (0, 1, 1)        %
# 55  56           rh     RH        r     (0, 1, 1)        %
# 56  57           rh     RH        r     (0, 1, 1)        %
# 57  58           rh     RH        r     (0, 1, 1)        %
# 58  59         rh2m     RH       2r     (0, 1, 1)        %
# 59  60         kidx     KX       kx     (0, 7, 2)        C
# 60  61         cape   CAPE  unknown     (0, 7, 6)     J/kg
# 61  62          cin    CIN  unknown     (0, 7, 7)     J/kg
# 62  63        dcape  DCAPE  unknown   (0, 7, 224)     J/kg
# 63  64  shr(0-1000)   VWSH     vwsh    (0, 2, 25)      s-1
# 64  65  shr(0-3000)   VWSH     vwsh    (0, 2, 25)      s-1
# 65  66  shr(0-6000)   VWSH     vwsh    (0, 2, 25)      s-1
# 66  67          bli    BLI      bli     (0, 7, 1)        K
# 67  68           hi     HI  unknown   (0, 1, 239)  unknown
# 68  69         pwat   PWAT     pwat     (0, 1, 3)    kg/kg
# 69  70          vis    VIS      vis    (0, 19, 0)        m
# 70  71         gust   GUST    i10fg    (0, 2, 22)      m/s
#
#                       层次类型    层次     统计类型    时效 数据类型        网格类型
# 0                  surface     0    accum  0-24   pf  regular_ll
# 1                  surface     0    accum  0-24   pf  regular_ll
# 2                  surface     0    accum  0-24   pf  regular_ll
# 3                  surface     0  instant    24   pf  regular_ll
# 4        heightAboveGround     2  instant    24   pf  regular_ll
# 5        heightAboveGround    10  instant    24   pf  regular_ll
# 6        heightAboveGround    10  instant    24   pf  regular_ll
# 7                  surface     0  instant    24   pf  regular_ll
# 8                  surface     0  instant    24   pf  regular_ll
# 9                  meanSea     0  instant    24   pf  regular_ll
# 10           isobaricInhPa  1000  instant    24   pf  regular_ll
# 11           isobaricInhPa   975  instant    24   pf  regular_ll
# 12           isobaricInhPa   950  instant    24   pf  regular_ll
# 13           isobaricInhPa   925  instant    24   pf  regular_ll
# 14           isobaricInhPa   900  instant    24   pf  regular_ll
# 15           isobaricInhPa   850  instant    24   pf  regular_ll
# 16           isobaricInhPa   700  instant    24   pf  regular_ll
# 17           isobaricInhPa   500  instant    24   pf  regular_ll
# 18           isobaricInhPa  1000  instant    24   pf  regular_ll
# 19           isobaricInhPa   975  instant    24   pf  regular_ll
# 20           isobaricInhPa   950  instant    24   pf  regular_ll
# 21           isobaricInhPa   925  instant    24   pf  regular_ll
# 22           isobaricInhPa   900  instant    24   pf  regular_ll
# 23           isobaricInhPa   850  instant    24   pf  regular_ll
# 24           isobaricInhPa   700  instant    24   pf  regular_ll
# 25           isobaricInhPa   500  instant    24   pf  regular_ll
# 26           isobaricInhPa  1000  instant    24   pf  regular_ll
# 27           isobaricInhPa   975  instant    24   pf  regular_ll
# 28           isobaricInhPa   950  instant    24   pf  regular_ll
# 29           isobaricInhPa   925  instant    24   pf  regular_ll
# 30           isobaricInhPa   900  instant    24   pf  regular_ll
# 31           isobaricInhPa   850  instant    24   pf  regular_ll
# 32           isobaricInhPa   700  instant    24   pf  regular_ll
# 33           isobaricInhPa   500  instant    24   pf  regular_ll
# 34           isobaricInhPa  1000  instant    24   pf  regular_ll
# 35           isobaricInhPa   975  instant    24   pf  regular_ll
# 36           isobaricInhPa   950  instant    24   pf  regular_ll
# 37           isobaricInhPa   925  instant    24   pf  regular_ll
# 38           isobaricInhPa   900  instant    24   pf  regular_ll
# 39           isobaricInhPa   850  instant    24   pf  regular_ll
# 40           isobaricInhPa   700  instant    24   pf  regular_ll
# 41           isobaricInhPa   500  instant    24   pf  regular_ll
# 42           isobaricInhPa  1000  instant    24   pf  regular_ll
# 43           isobaricInhPa   975  instant    24   pf  regular_ll
# 44           isobaricInhPa   950  instant    24   pf  regular_ll
# 45           isobaricInhPa   925  instant    24   pf  regular_ll
# 46           isobaricInhPa   900  instant    24   pf  regular_ll
# 47           isobaricInhPa   850  instant    24   pf  regular_ll
# 48           isobaricInhPa   700  instant    24   pf  regular_ll
# 49           isobaricInhPa   500  instant    24   pf  regular_ll
# 50           isobaricInhPa  1000  instant    24   pf  regular_ll
# 51           isobaricInhPa   975  instant    24   pf  regular_ll
# 52           isobaricInhPa   950  instant    24   pf  regular_ll
# 53           isobaricInhPa   925  instant    24   pf  regular_ll
# 54           isobaricInhPa   900  instant    24   pf  regular_ll
# 55           isobaricInhPa   850  instant    24   pf  regular_ll
# 56           isobaricInhPa   700  instant    24   pf  regular_ll
# 57           isobaricInhPa   500  instant    24   pf  regular_ll
# 58       heightAboveGround     2  instant    24   pf  regular_ll
# 59                 meanSea     0  instant    24   pf  regular_ll
# 60                 surface     0  instant    24   pf  regular_ll
# 61                 surface     0  instant    24   pf  regular_ll
# 62                 surface     0  instant    24   pf  regular_ll
# 63  heightAboveGroundLayer  1000  instant    24   pf  regular_ll
# 64  heightAboveGroundLayer  3000  instant    24   pf  regular_ll
# 65  heightAboveGroundLayer  6000  instant    24   pf  regular_ll
# 66                 surface     0  instant    24   pf  regular_ll
# 67                 surface     0  instant    24   pf  regular_ll
# 68              atmosphere     0  instant    24   pf  regular_ll
# 69                 surface     0  instant    24   pf  regular_ll
# 70       heightAboveGround    10  instant    24   pf  regular_ll
