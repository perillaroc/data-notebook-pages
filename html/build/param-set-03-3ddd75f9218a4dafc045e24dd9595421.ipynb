# %% [markdown]
# # MESO-3KM要素清单：180-305

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 等压面：水凝物与云量

# %% [markdown]
# ### 层次
#
# 21 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100

# %% [markdown]
# ### 云水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 云水混合比 | qc | CLMR | clwmr | (0, 1, 22) | pl | 21层 | 180-200 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CLMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 180

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="clwmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 188

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qc",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 197

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 22},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 200

# %% [markdown]
# ### 雨水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 雨水混合比 | qr | RWMR | rwmr | (0, 1, 24) | pl | 21层 | 201-221 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RWMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 201

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="rwmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 209

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qr",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 218

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 24},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 221

# %% [markdown]
# ### 冰水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 冰水混合比 | qi | ICMR | icmr | (0, 1, 23) | pl | 21层 | 222-242 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ICMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 222

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="icmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 230

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qi",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 239

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 23},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 242

# %% [markdown]
# ### 雪水混合比

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 雪水混合比 | qs | SNMR | snmr | (0, 1, 25) | pl | 21层 | 243-263 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SNMR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 243

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="snmr",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 251

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qs",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 260

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 25},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 263

# %% [markdown]
# ### 霰

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 霰 | graupel | GRLE | grle | (0, 1, 32) | pl | 21层 | 264-284 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="GRLE",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 264

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="grle",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 272

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="graupel",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 281

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 32},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 284

# %% [markdown]
# ### 云量

# %% [markdown]
# | 要素名 | cemc | wgrib2 | eccodes | GRIB Key | 层次类型 | 层次 | 编号 |
# |---|---|---|---|---|---|---|---|
# | 云量 | cc | CDCC | ccl | (0, 6, 22) | pl | 21层 | 285-305 |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CDCC",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 285

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ccl",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 293

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cc",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 302

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 22},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 305
