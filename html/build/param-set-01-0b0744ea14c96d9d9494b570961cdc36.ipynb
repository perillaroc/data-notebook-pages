# %% [markdown]
# # REPS要素清单：1-10

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

reps_grib2_orig_file_path = get_data_file("cma-reps")
reps_grib2_orig_file_path

# %% [markdown]
# ## 降水与地面要素

# %% [markdown]
# ### 对流降水

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 1 | rainc | ACPCP | acpcp | (0, 1, 10) | mm | surface | 0 | accum | 0-24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="ACPCP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="acpcp",
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="rainc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 10},
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %% [markdown]
# ### 总降水

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 2 | rain | APCP | — | (0, 1, 8) | mm | surface | 0 | accum | 0-24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="APCP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="rain",
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 8},
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %% [markdown]
# ### 降雪

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 3 | sf | ASNOW | — | (0, 1, 29) | m | surface | 0 | accum | 0-24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="ASNOW",
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="sf",
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 29},
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %% [markdown]
# ### 地表温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 4 | ts | TMP | t | (0, 0, 0) | K | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="TMP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="t",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="ts",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %% [markdown]
# ### 2米温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 5 | t2m | TMP | 2t | (0, 0, 0) | K | heightAboveGround | 2 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="TMP",
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="2t",
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="t2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %% [markdown]
# ### 10米U风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 6 | u10m | UGRD | 10u | (0, 2, 2) | m/s | heightAboveGround | 10 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="UGRD",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="10u",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="u10m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 2},
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %% [markdown]
# ### 10米V风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 7 | v10m | VGRD | 10v | (0, 2, 3) | m/s | heightAboveGround | 10 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VGRD",
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="10v",
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="v10m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %% [markdown]
# ### 组合雷达反射率

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 8 | cdbz | CR | — | (0, 16, 224) | dbz | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="CR",
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="cdbz",
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 16, "parameterNumber": 224},
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %% [markdown]
# ### 雪深

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 9 | sd | SNOD | sde | (0, 1, 11) | m | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="SNOD",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="sde",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="sd",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 11},
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %% [markdown]
# ## 海平面气压

# %% [markdown]
# ### 海平面气压

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 10 | psl | PRMSL | prmsl | (0, 3, 1) | Pa | meanSea | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="PRMSL",
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="prmsl",
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="psl",
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 1},
    lazy=True
)
assert field.attrs["GRIB_count"] == 10
