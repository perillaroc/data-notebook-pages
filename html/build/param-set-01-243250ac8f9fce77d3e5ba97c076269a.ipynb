# %% [markdown]
# # MESO-3KM要素清单：1-53

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 降水

# %% [markdown]
# ### 总累计降水

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 1 | rain | APCP | unknown | (0, 1, 8) | mm | surface | 0 | accum | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="APCP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="rain",
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 8},
    lazy=True
)
assert field.attrs["GRIB_count"] == 1

# %% [markdown]
# ### 降雪

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 2 | sf | ASNOW | unknown | (0, 1, 29) | m | surface | 0 | accum | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ASNOW",
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sf",
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 29},
    lazy=True
)
assert field.attrs["GRIB_count"] == 2

# %% [markdown]
# ## 地表温度与辐射通量

# %% [markdown]
# ### 地表温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 3 | ts | TMP | t | (0, 0, 0) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TMP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t",
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ts",
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 3

# %% [markdown]
# ### 净长波辐射通量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 4 | glw | NLWRF | str | (0, 5, 5) | w/m2 | surface | 0 | accum | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="NLWRF",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="str",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="glw",
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 5, "parameterNumber": 5},
    lazy=True
)
assert field.attrs["GRIB_count"] == 4

# %% [markdown]
# ### 净短波辐射通量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 5 | gsw | NSWRF | ssr | (0, 4, 9) | w/m2 | surface | 0 | accum | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="NSWRF",
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ssr",
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="gsw",
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 4, "parameterNumber": 9},
    lazy=True
)
assert field.attrs["GRIB_count"] == 5

# %% [markdown]
# ### 感热通量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 6 | sshf | HFLUX | hflux | (2, 0, 24) | ws/m2 | surface | 0 | accum | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HFLUX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="hflux",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sshf",
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 2, "parameterCategory": 0, "parameterNumber": 24},
    lazy=True
)
assert field.attrs["GRIB_count"] == 6

# %% [markdown]
# ### 地表水汽通量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 7 | qfxsfc |  | unknown | (0, 1, 229) | kg/(m2.s) | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qfxsfc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 229},
    lazy=True
)
assert field.attrs["GRIB_count"] == 7

# %% [markdown]
# ## 地形

# %% [markdown]
# ### 地形高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 8 | zs | HGT | orog | (0, 3, 5) | Gpm | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HGT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="orog",
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="zs",
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 5},
    lazy=True
)
assert field.attrs["GRIB_count"] == 8

# %% [markdown]
# ## 近地面要素

# %% [markdown]
# ### 2米比湿

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 9 | q2m | SPFH | 2sh | (0, 1, 0) | kg/kg | heightAboveGround | 2 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SPFH",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="2sh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="q2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 9

# %% [markdown]
# ### 2米温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 10 | t2m | TMP | 2t | (0, 0, 0) | K | heightAboveGround | 2 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TMP",
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="2t",
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 10

# %% [markdown]
# ### 10米U风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 11 | u10m | UGRD | 10u | (0, 2, 2) | m/s | heightAboveGround | 10 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="UGRD",
    lazy=True
)
assert field.attrs["GRIB_count"] == 11

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="10u",
    lazy=True
)
assert field.attrs["GRIB_count"] == 11

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u10m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 11

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 2},
    lazy=True
)
assert field.attrs["GRIB_count"] == 11

# %% [markdown]
# ### 10米V风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 12 | v10m | VGRD | 10v | (0, 2, 3) | m/s | heightAboveGround | 10 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="VGRD",
    lazy=True
)
assert field.attrs["GRIB_count"] == 12

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="10v",
    lazy=True
)
assert field.attrs["GRIB_count"] == 12

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v10m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 12

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 12

# %% [markdown]
# ## 云量

# %% [markdown]
# ### 总云量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 13 | tcc | TCDC | tcc | (0, 6, 1) | % | entireAtmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TCDC",
    lazy=True
)
assert field.attrs["GRIB_count"] == 13

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 13

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 13

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 1},
    lazy=True
)
assert field.attrs["GRIB_count"] == 13

# %% [markdown]
# ### 低云量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 14 | lcc | LCDC | lcc | (0, 6, 3) | % | entireAtmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="LCDC",
    lazy=True
)
assert field.attrs["GRIB_count"] == 14

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="lcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 14

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="lcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 14

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 14

# %% [markdown]
# ### 中云量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 15 | mcc | MCDC | mcc | (0, 6, 4) | % | entireAtmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="MCDC",
    lazy=True
)
assert field.attrs["GRIB_count"] == 15

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="mcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 15

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="mcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 15

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 4},
    lazy=True
)
assert field.attrs["GRIB_count"] == 15

# %% [markdown]
# ### 高云量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 16 | hcc | HCDC | hcc | (0, 6, 5) | % | entireAtmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HCDC",
    lazy=True
)
assert field.attrs["GRIB_count"] == 16

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="hcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 16

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="hcc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 16

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 5},
    lazy=True
)
assert field.attrs["GRIB_count"] == 16

# %% [markdown]
# ## 整层水量

# %% [markdown]
# ### 总柱状比湿

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 17 | tvw | TCIWV | unknown | (0, 1, 64) | kg/m2 | atmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TCIWV",
    lazy=True
)
assert field.attrs["GRIB_count"] == 17

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tvw",
    lazy=True
)
assert field.attrs["GRIB_count"] == 17

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 64},
    lazy=True
)
assert field.attrs["GRIB_count"] == 17

# %% [markdown]
# ### 总柱状云水

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 18 | tcw | TCOLW | unknown | (0, 1, 69) | kg/m2 | atmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TCOLW",
    lazy=True
)
assert field.attrs["GRIB_count"] == 18

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tcw",
    lazy=True
)
assert field.attrs["GRIB_count"] == 18

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 69},
    lazy=True
)
assert field.attrs["GRIB_count"] == 18

# %% [markdown]
# ### 总柱状云冰

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 19 | tiw | TCOLI | unknown | (0, 1, 70) | kg/m2 | atmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TCOLI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 19

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tiw",
    lazy=True
)
assert field.attrs["GRIB_count"] == 19

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 70},
    lazy=True
)
assert field.attrs["GRIB_count"] == 19

# %% [markdown]
# ## 边界层与雷达

# %% [markdown]
# ### 边界层高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 20 | pblh | HPBL | blh | (0, 3, 18) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HPBL",
    lazy=True
)
assert field.attrs["GRIB_count"] == 20

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="blh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 20

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pblh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 20

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 18},
    lazy=True
)
assert field.attrs["GRIB_count"] == 20

# %% [markdown]
# ### 雷达组合反射率

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 21 | cdbz | CR | unknown | (0, 16, 224) | dbz | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CR",
    lazy=True
)
assert field.attrs["GRIB_count"] == 21

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cdbz",
    lazy=True
)
assert field.attrs["GRIB_count"] == 21

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 16, "parameterNumber": 224},
    lazy=True
)
assert field.attrs["GRIB_count"] == 21

# %% [markdown]
# ## 最大统计与强对流诊断

# %% [markdown]
# ### 最大垂直速度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 22 | wmax#1 | DZDT | wz | (0, 2, 9) | m/s | isobaricInhPa | 1000 | max | 23-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DZDT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 22

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="wz",
    lazy=True
)
assert field.attrs["GRIB_count"] == 22

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="wmax#1",
    lazy=True
)
assert field.attrs["GRIB_count"] == 22

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 9},
    lazy=True
)
assert field.attrs["GRIB_count"] == 22

# %% [markdown]
# ### 最大10米U风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 23 | u10mmax#1 | UGRD | 10u | (0, 2, 2) | m/s | heightAboveGround | 10 | max | 23-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u10mmax#1",
    lazy=True
)
assert field.attrs["GRIB_count"] == 23

# %% [markdown]
# ### 最大10米V风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 24 | v10mmax#1 | VGRD | 10v | (0, 2, 3) | m/s | heightAboveGround | 10 | max | 23-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v10mmax#1",
    lazy=True
)
assert field.attrs["GRIB_count"] == 24

# %% [markdown]
# ### 最大组合雷达反射率

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 25 | cdbzmax#1 | CR | unknown | (0, 16, 224) | dbz | surface | 0 | max | 23-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cdbzmax#1",
    lazy=True
)
assert field.attrs["GRIB_count"] == 25

# %% [markdown]
# ### 雷达回波顶

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 26 | echotop | RETOP | unknown | (0, 16, 3) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RETOP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 26

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="echotop",
    lazy=True
)
assert field.attrs["GRIB_count"] == 26

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 16, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 26

# %% [markdown]
# ### 2000-5000米最大上升螺旋度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 27 | uhmax(2000-5000) | UPHL | unknown | (0, 7, 15) | m2/s2 | heightAboveGroundLayer | 5000 | max | 0-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="UPHL",
    lazy=True
)
assert field.attrs["GRIB_count"] == 27

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="uhmax(2000-5000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 27

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 15},
    lazy=True
)
assert field.attrs["GRIB_count"] == 27

# %% [markdown]
# ### 近地面总体理查森数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 28 | risfc | RI | unknown | (0, 7, 12) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 28

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="risfc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 28

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 12},
    lazy=True
)
assert field.attrs["GRIB_count"] == 28

# %% [markdown]
# ### 边界层总体理查森数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 29 | ripbl | RI | unknown | (0, 7, 12) | unknown | mixingLayer | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RI",
    level_type="mixingLayer",
    level=0,
    lazy=True
)
assert field.attrs["GRIB_count"] == 29

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ripbl",
    level_type="mixingLayer",
    level=0,
    lazy=True
)
assert field.attrs["GRIB_count"] == 29

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 12},
    level_type="mixingLayer",
    level=0,
    lazy=True
)
assert field.attrs["GRIB_count"] == 29

# %% [markdown]
# ### 5分钟最大降水

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 30 | rain5max |  | unknown | (0, 1, 241) | mm | surface | 0 | max | 23-24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="rain5max",
    lazy=True
)
assert field.attrs["GRIB_count"] == 30

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 241},
    lazy=True
)
assert field.attrs["GRIB_count"] == 30

# %% [markdown]
# ### 0-600米最大垂直风切变矢量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 31 | shrmax(0-600) |  | unknown | (0, 2, 237) | m/s | heightAboveGroundLayer | 600 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="shrmax(0-600)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 31

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 237},
    lazy=True
)
assert field.attrs["GRIB_count"] == 31

# %% [markdown]
# ### 0-600米最大垂直风切变方向

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 32 | shrmaxdir(0-600) |  | unknown | (0, 2, 238) | degree | heightAboveGroundLayer | 600 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="shrmaxdir(0-600)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 32

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 238},
    lazy=True
)
assert field.attrs["GRIB_count"] == 32

# %% [markdown]
# ### 最大雷达回波的高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 33 | dbzmaxh |  | unknown | (0, 16, 226) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="dbzmaxh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 33

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 16, "parameterNumber": 226},
    lazy=True
)
assert field.attrs["GRIB_count"] == 33

# %% [markdown]
# ## 气压

# %% [markdown]
# ### 地面气压

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 34 | ps | PRES | sp | (0, 3, 0) | Pa | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="PRES",
    lazy=True
)
assert field.attrs["GRIB_count"] == 34

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sp",
    lazy=True
)
assert field.attrs["GRIB_count"] == 34

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ps",
    lazy=True
)
assert field.attrs["GRIB_count"] == 34

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 34

# %% [markdown]
# ### 海平面气压

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 35 | psl | PRMSL | prmsl | (0, 3, 1) | Pa | meanSea | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="PRMSL",
    lazy=True
)
assert field.attrs["GRIB_count"] == 35

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="prmsl",
    lazy=True
)
assert field.attrs["GRIB_count"] == 35

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="psl",
    lazy=True
)
assert field.attrs["GRIB_count"] == 35

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 1},
    lazy=True
)
assert field.attrs["GRIB_count"] == 35

# %% [markdown]
# ## 高度层风

# %% [markdown]
# ### 层次
#
# 9 层列表（高度，米）：
#
# - 30
# - 50
# - 70
# - 100
# - 120
# - 140
# - 160
# - 180
# - 200

# %% [markdown]
# ### 东西风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 36-44 | u | UGRD | u | (0, 2, 2) | m/s | heightAboveGround | 9层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="UGRD",
    level_type="heightAboveGround",
    level=30,
    lazy=True
)
assert field.attrs["GRIB_count"] == 36

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u",
    level_type="heightAboveGround",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 39

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="u",
    level_type="heightAboveGround",
    level=160,
    lazy=True
)
assert field.attrs["GRIB_count"] == 42

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 2},
    level_type="heightAboveGround",
    level=200,
    lazy=True
)
assert field.attrs["GRIB_count"] == 44

# %% [markdown]
# ### 南北风

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 45-53 | v | VGRD | v | (0, 2, 3) | m/s | heightAboveGround | 9层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="VGRD",
    level_type="heightAboveGround",
    level=30,
    lazy=True
)
assert field.attrs["GRIB_count"] == 45

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v",
    level_type="heightAboveGround",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 48

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="v",
    level_type="heightAboveGround",
    level=160,
    lazy=True
)
assert field.attrs["GRIB_count"] == 51

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 3},
    level_type="heightAboveGround",
    level=200,
    lazy=True
)
assert field.attrs["GRIB_count"] == 53
