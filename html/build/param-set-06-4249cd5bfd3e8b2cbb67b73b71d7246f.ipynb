# %% [markdown]
# # MESO-3KM要素清单：526-575

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 稳定度指数

# %% [markdown]
# ### K指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 526 | kidx | KX | kx | (0, 7, 2) | C | meanSea | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="KX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 526

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="kx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 526

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="kidx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 526

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 2},
    lazy=True
)
assert field.attrs["GRIB_count"] == 526

# %% [markdown]
# ### 强天气胁迫指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 527 | sweatidx | SX | sx | (0, 7, 5) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 527

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 527

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sweatidx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 527

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 5},
    lazy=True
)
assert field.attrs["GRIB_count"] == 527

# %% [markdown]
# ### 对流有效位能

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 528 | cape | CAPE | unknown | (0, 7, 6) | J/kg | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CAPE",
    lazy=True
)
assert field.attrs["GRIB_count"] == 528

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cape",
    lazy=True
)
assert field.attrs["GRIB_count"] == 528

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 6},
    lazy=True
)
assert field.attrs["GRIB_count"] == 528

# %% [markdown]
# ### 对流抑制能量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 529 | cin | CIN | unknown | (0, 7, 7) | J/kg | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CIN",
    lazy=True
)
assert field.attrs["GRIB_count"] == 529

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cin",
    lazy=True
)
assert field.attrs["GRIB_count"] == 529

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 7},
    lazy=True
)
assert field.attrs["GRIB_count"] == 529

# %% [markdown]
# ### 气块抬升指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 530 | pli | PLI | pli | (0, 7, 0) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="PLI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 530

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pli",
    lazy=True
)
assert field.attrs["GRIB_count"] == 530

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pli",
    lazy=True
)
assert field.attrs["GRIB_count"] == 530

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 530

# %% [markdown]
# ### 抬升凝结高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 531 | pc |  | unknown | (0, 1, 228) | Pa | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pc",
    lazy=True
)
assert field.attrs["GRIB_count"] == 531

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 228},
    lazy=True
)
assert field.attrs["GRIB_count"] == 531

# %% [markdown]
# ### 下沉对流有效位能

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 532 | dcape | DCAPE | unknown | (0, 7, 224) | J/kg | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DCAPE",
    lazy=True
)
assert field.attrs["GRIB_count"] == 532

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="dcape",
    lazy=True
)
assert field.attrs["GRIB_count"] == 532

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 224},
    lazy=True
)
assert field.attrs["GRIB_count"] == 532

# %% [markdown]
# ### 0-1000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 533 | shr(0-1000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 1000 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="VWSH",
    lazy=True
)
assert field.attrs["GRIB_count"] == 533

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="vwsh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 533

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="shr(0-1000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 533

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 25},
    lazy=True
)
assert field.attrs["GRIB_count"] == 533

# %% [markdown]
# ### 0-3000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 534 | shr(0-3000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 3000 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="shr(0-3000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 534

# %% [markdown]
# ### 0-6000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 535 | shr(0-6000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 6000 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="shr(0-6000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 535

# %% [markdown]
# ### 最优抬升指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 536 | bli | BLI | bli | (0, 7, 1) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="BLI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 536

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="bli",
    lazy=True
)
assert field.attrs["GRIB_count"] == 536

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="bli",
    lazy=True
)
assert field.attrs["GRIB_count"] == 536

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 1},
    lazy=True
)
assert field.attrs["GRIB_count"] == 536

# %% [markdown]
# ## 等压面雷达反射率

# %% [markdown]
# ### 层次
#
# 21 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100

# %% [markdown]
# ### 雷达反射率

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 537-557 | dbz |  | unknown | (0, 16, 225) | dbz | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="dbz",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 537

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 16, "parameterNumber": 225},
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 545

# %% [markdown]
# ## 风暴螺旋度与其他指数

# %% [markdown]
# ### 0-1000米风暴螺旋度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 558 | srh(0-1000) | HLCY | hlcy | (0, 7, 8) | J/kg | heightAboveGroundLayer | 1000 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HLCY",
    lazy=True
)
assert field.attrs["GRIB_count"] == 558

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="hlcy",
    lazy=True
)
assert field.attrs["GRIB_count"] == 558

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="srh(0-1000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 558

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 8},
    lazy=True
)
assert field.attrs["GRIB_count"] == 558

# %% [markdown]
# ### 0-3000米风暴螺旋度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 559 | srh(0-3000) | HLCY | hlcy | (0, 7, 8) | J/kg | heightAboveGroundLayer | 3000 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="srh(0-3000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 559

# %% [markdown]
# ### 沙氏指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 560 | si | SHWINX | unknown | (0, 7, 13) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SHWINX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 560

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="si",
    lazy=True
)
assert field.attrs["GRIB_count"] == 560

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 13},
    lazy=True
)
assert field.attrs["GRIB_count"] == 560

# %% [markdown]
# ### 冰雹指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 561 | hi | HI | unknown | (0, 1, 239) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="HI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 561

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="hi",
    lazy=True
)
assert field.attrs["GRIB_count"] == 561

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 239},
    lazy=True
)
assert field.attrs["GRIB_count"] == 561

# %% [markdown]
# ### 大风指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 562 | wi |  | unknown | (0, 2, 236) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="wi",
    lazy=True
)
assert field.attrs["GRIB_count"] == 562

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 236},
    lazy=True
)
assert field.attrs["GRIB_count"] == 562

# %% [markdown]
# ### 总指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 563 | tti | TOTALX | totalx | (0, 7, 4) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TOTALX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 563

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="totalx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 563

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tti",
    lazy=True
)
assert field.attrs["GRIB_count"] == 563

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 4},
    lazy=True
)
assert field.attrs["GRIB_count"] == 563

# %% [markdown]
# ### 0度层高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 564 | ht0 |  | unknown | (0, 3, 225) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ht0",
    lazy=True
)
assert field.attrs["GRIB_count"] == 564

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 225},
    lazy=True
)
assert field.attrs["GRIB_count"] == 564

# %% [markdown]
# ### -20度层高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 565 | ht2 |  | unknown | (0, 3, 226) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ht2",
    lazy=True
)
assert field.attrs["GRIB_count"] == 565

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 3, "parameterNumber": 226},
    lazy=True
)
assert field.attrs["GRIB_count"] == 565

# %% [markdown]
# ### 风暴强度指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 566 | ssi |  | unknown | (0, 7, 225) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ssi",
    lazy=True
)
assert field.attrs["GRIB_count"] == 566

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 225},
    lazy=True
)
assert field.attrs["GRIB_count"] == 566

# %% [markdown]
# ## 可降水量、能见度与阵风

# %% [markdown]
# ### 整层可降水量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 567 | pwat | PWAT | pwat | (0, 1, 3) | kg/kg | atmosphere | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="PWAT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 567

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pwat",
    lazy=True
)
assert field.attrs["GRIB_count"] == 567

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="pwat",
    lazy=True
)
assert field.attrs["GRIB_count"] == 567

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 567

# %% [markdown]
# ### 能见度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 568 | vis | VIS | vis | (0, 19, 0) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="VIS",
    lazy=True
)
assert field.attrs["GRIB_count"] == 568

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="vis",
    lazy=True
)
assert field.attrs["GRIB_count"] == 568

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="vis",
    lazy=True
)
assert field.attrs["GRIB_count"] == 568

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 19, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 568

# %% [markdown]
# ### 阵风风速

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 569 | gust | GUST | i10fg | (0, 2, 22) | m/s | heightAboveGround | 10 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="GUST",
    lazy=True
)
assert field.attrs["GRIB_count"] == 569

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="i10fg",
    lazy=True
)
assert field.attrs["GRIB_count"] == 569

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="gust",
    lazy=True
)
assert field.attrs["GRIB_count"] == 569

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 22},
    lazy=True
)
assert field.attrs["GRIB_count"] == 569

# %% [markdown]
# ## 云与降水相态

# %% [markdown]
# ### 降水相态

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 570 | precitype | PTYPE | ptype | (0, 1, 19) | unknown | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="PTYPE",
    lazy=True
)
assert field.attrs["GRIB_count"] == 570

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ptype",
    lazy=True
)
assert field.attrs["GRIB_count"] == 570

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="precitype",
    lazy=True
)
assert field.attrs["GRIB_count"] == 570

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 19},
    lazy=True
)
assert field.attrs["GRIB_count"] == 570

# %% [markdown]
# ### 云顶高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 571 | cldt | CDCTOP | cdct | (0, 6, 12) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CDCTOP",
    lazy=True
)
assert field.attrs["GRIB_count"] == 571

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cdct",
    lazy=True
)
assert field.attrs["GRIB_count"] == 571

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cldt",
    lazy=True
)
assert field.attrs["GRIB_count"] == 571

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 12},
    lazy=True
)
assert field.attrs["GRIB_count"] == 571

# %% [markdown]
# ### 云底高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 572 | cldb | CDCB | unknown | (0, 6, 11) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CDCB",
    lazy=True
)
assert field.attrs["GRIB_count"] == 572

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="cldb",
    lazy=True
)
assert field.attrs["GRIB_count"] == 572

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 11},
    lazy=True
)
assert field.attrs["GRIB_count"] == 572

# %% [markdown]
# ### 云幂高度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 573 | ceiling | CEIL | ceil | (0, 6, 13) | m | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="CEIL",
    lazy=True
)
assert field.attrs["GRIB_count"] == 573

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ceil",
    lazy=True
)
assert field.attrs["GRIB_count"] == 573

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ceiling",
    lazy=True
)
assert field.attrs["GRIB_count"] == 573

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 6, "parameterNumber": 13},
    lazy=True
)
assert field.attrs["GRIB_count"] == 573

# %% [markdown]
# ## 卫星模拟亮温

# %% [markdown]
# ### 卫星红外通道模拟亮温

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 574 | bti |  | unknown | (0, 4, 228) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="bti",
    lazy=True
)
assert field.attrs["GRIB_count"] == 574

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 4, "parameterNumber": 228},
    lazy=True
)
assert field.attrs["GRIB_count"] == 574

# %% [markdown]
# ### 卫星水汽通道模拟亮温

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 575 | btv |  | unknown | (0, 4, 227) | K | surface | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="btv",
    lazy=True
)
assert field.attrs["GRIB_count"] == 575

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 4, "parameterNumber": 227},
    lazy=True
)
assert field.attrs["GRIB_count"] == 575
