# %% [markdown]
# # MESO-3KM要素清单：306-336

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 土壤温湿度

# %% [markdown]
# ### 层次
#
# 4 层列表（深度，厘米）：
#
# - 0-10cm
# - 10-30cm
# - 30-60cm
# - 60-100cm

# %% [markdown]
# ### 0-10厘米土壤温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 306 | st(0-10) | TMP | t | (0, 0, 0) | K | depthBelowLandLayer | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TMP",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 306

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 306

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="st(0-10)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 306

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 306

# %% [markdown]
# ### 土壤温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 307-309 | st | TMP | t | (0, 0, 0) | K | depthBelowLandLayer | 3层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="TMP",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.1,
        "second_level": 0.3,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 307

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="t",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.3,
        "second_level": 0.6,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 308

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="st",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 309

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 309

# %% [markdown]
# ### 0-10厘米土壤湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 310 | sw(0-10) | SPFH | q | (0, 1, 0) | kg/kg | depthBelowLandLayer | 0 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SPFH",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 310

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="q",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 310

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sw(0-10)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 310

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0,
        "second_level": 0.1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 310

# %% [markdown]
# ### 土壤湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 311-313 | sw | SPFH | q | (0, 1, 0) | kg/kg | depthBelowLandLayer | 3层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="SPFH",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.1,
        "second_level": 0.3,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 311

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="q",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.3,
        "second_level": 0.6,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 312

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="sw",
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 313

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 0},
    level_type="depthBelowLandLayer",
    level={
        "first_level": 0.6,
        "second_level": 1,
    },
    lazy=True
)
assert field.attrs["GRIB_count"] == 313

# %% [markdown]
# ## 等压面相对湿度

# %% [markdown]
# ### 层次
#
# 21 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100

# %% [markdown]
# ### 相对湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 314-334 | rh | RH | r | (0, 1, 1) | % | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RH",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 314

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="r",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 322

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="rh",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 331

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 334

# %% [markdown]
# ## 近地面湿度

# %% [markdown]
# ### 2米相对湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 335 | rh2m | RH | 2r | (0, 1, 1) | % | heightAboveGround | 2 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RH",
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 335

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="2r",
    lazy=True
)
assert field.attrs["GRIB_count"] == 335

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="rh2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 335

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 335

# %% [markdown]
# ### 2米露点温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 336 | td2m | DPT | 2d | (0, 0, 6) | K | heightAboveGround | 2 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DPT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="2d",
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="td2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 336

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 6},
    lazy=True
)
assert field.attrs["GRIB_count"] == 336
