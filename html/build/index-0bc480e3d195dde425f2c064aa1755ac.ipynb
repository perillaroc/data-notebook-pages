# %% [markdown]
# # CMA-GEPS

# %% [markdown]
# CMA-GEPS 基础 GRIB2 数据文件有 130 个要素场。
#
# 本页文件为集合预报成员 1（文件名后缀 `-m001.grib2`）；所有要素均为集合扰动预报（pf）。

# %%
import pandas as pd

# %%
from data_notebook.data import get_data_file

geps_grib2_orig_file_path = get_data_file("cma-geps")
geps_grib2_orig_file_path
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-geps/grib2/orig/Z_NAFP_C_BABJ_20260811000000_P_NWPC-GRAPES-GEPS-GLB-02400-m001.grib2')

# %% [markdown]
# ## 要素列表
#
# 使用 reki 识别全部 GRIB2 消息头中的要素，并结合内置要素注册表生成要素列表。

# %%
from IPython.display import display
from data_notebook import get_grib2_inventory

inventory = get_grib2_inventory(geps_grib2_orig_file_path)
with pd.option_context("display.max_rows", None):
    display(inventory)
# Out:
#       序号          要素名 wgrib2  eccodes      GRIB key       单位  \
# 0      1            h    HGT       gh     (0, 3, 5)      Gpm
# 1      2            h    HGT       gh     (0, 3, 5)      Gpm
# 2      3            h    HGT       gh     (0, 3, 5)      Gpm
# 3      4            h    HGT       gh     (0, 3, 5)      Gpm
# 4      5            h    HGT       gh     (0, 3, 5)      Gpm
# 5      6            h    HGT       gh     (0, 3, 5)      Gpm
# 6      7            h    HGT       gh     (0, 3, 5)      Gpm
# 7      8            h    HGT       gh     (0, 3, 5)      Gpm
# 8      9            h    HGT       gh     (0, 3, 5)      Gpm
# 9     10            h    HGT       gh     (0, 3, 5)      Gpm
# 10    11            h    HGT       gh     (0, 3, 5)      Gpm
# 11    12            h    HGT       gh     (0, 3, 5)      Gpm
# 12    13            h    HGT       gh     (0, 3, 5)      Gpm
# 13    14            h    HGT       gh     (0, 3, 5)      Gpm
# 14    15            h    HGT       gh     (0, 3, 5)      Gpm
# 15    16            h    HGT       gh     (0, 3, 5)      Gpm
# 16    17            h    HGT       gh     (0, 3, 5)      Gpm
# 17    18            t    TMP        t     (0, 0, 0)        K
# 18    19            t    TMP        t     (0, 0, 0)        K
# 19    20            t    TMP        t     (0, 0, 0)        K
# 20    21            t    TMP        t     (0, 0, 0)        K
# 21    22            t    TMP        t     (0, 0, 0)        K
# 22    23            t    TMP        t     (0, 0, 0)        K
# 23    24            t    TMP        t     (0, 0, 0)        K
# 24    25            t    TMP        t     (0, 0, 0)        K
# 25    26            t    TMP        t     (0, 0, 0)        K
# 26    27            t    TMP        t     (0, 0, 0)        K
# 27    28            t    TMP        t     (0, 0, 0)        K
# 28    29            t    TMP        t     (0, 0, 0)        K
# 29    30            t    TMP        t     (0, 0, 0)        K
# 30    31            t    TMP        t     (0, 0, 0)        K
# 31    32            t    TMP        t     (0, 0, 0)        K
# 32    33            t    TMP        t     (0, 0, 0)        K
# 33    34            t    TMP        t     (0, 0, 0)        K
# 34    35            u   UGRD        u     (0, 2, 2)      m/s
# 35    36            u   UGRD        u     (0, 2, 2)      m/s
# 36    37            u   UGRD        u     (0, 2, 2)      m/s
# 37    38            u   UGRD        u     (0, 2, 2)      m/s
# 38    39            u   UGRD        u     (0, 2, 2)      m/s
# 39    40            u   UGRD        u     (0, 2, 2)      m/s
# 40    41            u   UGRD        u     (0, 2, 2)      m/s
# 41    42            u   UGRD        u     (0, 2, 2)      m/s
# 42    43            u   UGRD        u     (0, 2, 2)      m/s
# 43    44            u   UGRD        u     (0, 2, 2)      m/s
# 44    45            u   UGRD        u     (0, 2, 2)      m/s
# 45    46            u   UGRD        u     (0, 2, 2)      m/s
# 46    47            u   UGRD        u     (0, 2, 2)      m/s
# 47    48            u   UGRD        u     (0, 2, 2)      m/s
# 48    49            u   UGRD        u     (0, 2, 2)      m/s
# 49    50            u   UGRD        u     (0, 2, 2)      m/s
# 50    51            u   UGRD        u     (0, 2, 2)      m/s
# 51    52            v   VGRD        v     (0, 2, 3)      m/s
# 52    53            v   VGRD        v     (0, 2, 3)      m/s
# 53    54            v   VGRD        v     (0, 2, 3)      m/s
# 54    55            v   VGRD        v     (0, 2, 3)      m/s
# 55    56            v   VGRD        v     (0, 2, 3)      m/s
# 56    57            v   VGRD        v     (0, 2, 3)      m/s
# 57    58            v   VGRD        v     (0, 2, 3)      m/s
# 58    59            v   VGRD        v     (0, 2, 3)      m/s
# 59    60            v   VGRD        v     (0, 2, 3)      m/s
# 60    61            v   VGRD        v     (0, 2, 3)      m/s
# 61    62            v   VGRD        v     (0, 2, 3)      m/s
# 62    63            v   VGRD        v     (0, 2, 3)      m/s
# 63    64            v   VGRD        v     (0, 2, 3)      m/s
# 64    65            v   VGRD        v     (0, 2, 3)      m/s
# 65    66            v   VGRD        v     (0, 2, 3)      m/s
# 66    67            v   VGRD        v     (0, 2, 3)      m/s
# 67    68            v   VGRD        v     (0, 2, 3)      m/s
# 68    69            q   SPFH        q     (0, 1, 0)    kg/kg
# 69    70            q   SPFH        q     (0, 1, 0)    kg/kg
# 70    71            q   SPFH        q     (0, 1, 0)    kg/kg
# 71    72            q   SPFH        q     (0, 1, 0)    kg/kg
# 72    73            q   SPFH        q     (0, 1, 0)    kg/kg
# 73    74            q   SPFH        q     (0, 1, 0)    kg/kg
# 74    75            q   SPFH        q     (0, 1, 0)    kg/kg
# 75    76            q   SPFH        q     (0, 1, 0)    kg/kg
# 76    77            q   SPFH        q     (0, 1, 0)    kg/kg
# 77    78            q   SPFH        q     (0, 1, 0)    kg/kg
# 78    79            q   SPFH        q     (0, 1, 0)    kg/kg
# 79    80            q   SPFH        q     (0, 1, 0)    kg/kg
# 80    81            q   SPFH        q     (0, 1, 0)    kg/kg
# 81    82            q   SPFH        q     (0, 1, 0)    kg/kg
# 82    83            q   SPFH        q     (0, 1, 0)    kg/kg
# 83    84            q   SPFH        q     (0, 1, 0)    kg/kg
# 84    85            q   SPFH        q     (0, 1, 0)    kg/kg
# 85    86         u10m   UGRD      10u     (0, 2, 2)      m/s
# 86    87         v10m   VGRD      10v     (0, 2, 3)      m/s
# 87    88          t2m    TMP       2t     (0, 0, 0)        K
# 88    89          psl  PRMSL    prmsl     (0, 3, 1)       Pa
# 89    90           ps   PRES       sp     (0, 3, 0)       Pa
# 90    91         rh2m     RH       2r     (0, 1, 1)        %
# 91    92           zs    HGT     orog     (0, 3, 5)      Gpm
# 92    93        rainc  ACPCP    acpcp    (0, 1, 10)       mm
# 93    94       rainnc  NCPCP    ncpcp     (0, 1, 9)       mm
# 94    95         rain   APCP  unknown     (0, 1, 8)       mm
# 95    96           sf  ASNOW  unknown    (0, 1, 29)        m
# 96    97          tcc   TCDC      tcc     (0, 6, 1)        %
# 97    98          lcc   LCDC      lcc     (0, 6, 3)        %
# 98    99          mcc   MCDC      mcc     (0, 6, 4)        %
# 99   100          hcc   HCDC      hcc     (0, 6, 5)        %
# 100  101         kidx     KX       kx     (0, 7, 2)        C
# 101  102         cape   CAPE  unknown     (0, 7, 6)     J/kg
# 102  103          cin    CIN  unknown     (0, 7, 7)     J/kg
# 103  104        dcape  DCAPE  unknown   (0, 7, 224)     J/kg
# 104  105  shr(0-1000)   VWSH     vwsh    (0, 2, 25)      s-1
# 105  106  shr(0-3000)   VWSH     vwsh    (0, 2, 25)      s-1
# 106  107  shr(0-6000)   VWSH     vwsh    (0, 2, 25)      s-1
# 107  108          bli    BLI      bli     (0, 7, 1)        K
# 108  109         cdbz     CR  unknown  (0, 16, 224)      dbz
# 109  110           hi     HI  unknown   (0, 1, 239)  unknown
# 110  111         pwat   PWAT     pwat     (0, 1, 3)    kg/kg
# 111  112           rh     RH        r     (0, 1, 1)        %
# 112  113           rh     RH        r     (0, 1, 1)        %
# 113  114           rh     RH        r     (0, 1, 1)        %
# 114  115           rh     RH        r     (0, 1, 1)        %
# 115  116           rh     RH        r     (0, 1, 1)        %
# 116  117           rh     RH        r     (0, 1, 1)        %
# 117  118           rh     RH        r     (0, 1, 1)        %
# 118  119           rh     RH        r     (0, 1, 1)        %
# 119  120           rh     RH        r     (0, 1, 1)        %
# 120  121           rh     RH        r     (0, 1, 1)        %
# 121  122           rh     RH        r     (0, 1, 1)        %
# 122  123           rh     RH        r     (0, 1, 1)        %
# 123  124           rh     RH        r     (0, 1, 1)        %
# 124  125           rh     RH        r     (0, 1, 1)        %
# 125  126           rh     RH        r     (0, 1, 1)        %
# 126  127           rh     RH        r     (0, 1, 1)        %
# 127  128           rh     RH        r     (0, 1, 1)        %
# 128  129         gust   GUST    i10fg    (0, 2, 22)      m/s
# 129  130          vis    VIS      vis    (0, 19, 0)        m
#
#                        层次类型    层次     统计类型    时效 数据类型        网格类型
# 0             isobaricInhPa   100  instant    24   pf  regular_ll
# 1             isobaricInhPa   200  instant    24   pf  regular_ll
# 2             isobaricInhPa   300  instant    24   pf  regular_ll
# 3             isobaricInhPa   400  instant    24   pf  regular_ll
# 4             isobaricInhPa   500  instant    24   pf  regular_ll
# 5             isobaricInhPa   550  instant    24   pf  regular_ll
# 6             isobaricInhPa   600  instant    24   pf  regular_ll
# 7             isobaricInhPa   650  instant    24   pf  regular_ll
# 8             isobaricInhPa   700  instant    24   pf  regular_ll
# 9             isobaricInhPa   750  instant    24   pf  regular_ll
# 10            isobaricInhPa   800  instant    24   pf  regular_ll
# 11            isobaricInhPa   850  instant    24   pf  regular_ll
# 12            isobaricInhPa   900  instant    24   pf  regular_ll
# 13            isobaricInhPa   925  instant    24   pf  regular_ll
# 14            isobaricInhPa   950  instant    24   pf  regular_ll
# 15            isobaricInhPa   975  instant    24   pf  regular_ll
# 16            isobaricInhPa  1000  instant    24   pf  regular_ll
# 17            isobaricInhPa   100  instant    24   pf  regular_ll
# 18            isobaricInhPa   200  instant    24   pf  regular_ll
# 19            isobaricInhPa   300  instant    24   pf  regular_ll
# 20            isobaricInhPa   400  instant    24   pf  regular_ll
# 21            isobaricInhPa   500  instant    24   pf  regular_ll
# 22            isobaricInhPa   550  instant    24   pf  regular_ll
# 23            isobaricInhPa   600  instant    24   pf  regular_ll
# 24            isobaricInhPa   650  instant    24   pf  regular_ll
# 25            isobaricInhPa   700  instant    24   pf  regular_ll
# 26            isobaricInhPa   750  instant    24   pf  regular_ll
# 27            isobaricInhPa   800  instant    24   pf  regular_ll
# 28            isobaricInhPa   850  instant    24   pf  regular_ll
# 29            isobaricInhPa   900  instant    24   pf  regular_ll
# 30            isobaricInhPa   925  instant    24   pf  regular_ll
# 31            isobaricInhPa   950  instant    24   pf  regular_ll
# 32            isobaricInhPa   975  instant    24   pf  regular_ll
# 33            isobaricInhPa  1000  instant    24   pf  regular_ll
# 34            isobaricInhPa   100  instant    24   pf  regular_ll
# 35            isobaricInhPa   200  instant    24   pf  regular_ll
# 36            isobaricInhPa   300  instant    24   pf  regular_ll
# 37            isobaricInhPa   400  instant    24   pf  regular_ll
# 38            isobaricInhPa   500  instant    24   pf  regular_ll
# 39            isobaricInhPa   550  instant    24   pf  regular_ll
# 40            isobaricInhPa   600  instant    24   pf  regular_ll
# 41            isobaricInhPa   650  instant    24   pf  regular_ll
# 42            isobaricInhPa   700  instant    24   pf  regular_ll
# 43            isobaricInhPa   750  instant    24   pf  regular_ll
# 44            isobaricInhPa   800  instant    24   pf  regular_ll
# 45            isobaricInhPa   850  instant    24   pf  regular_ll
# 46            isobaricInhPa   900  instant    24   pf  regular_ll
# 47            isobaricInhPa   925  instant    24   pf  regular_ll
# 48            isobaricInhPa   950  instant    24   pf  regular_ll
# 49            isobaricInhPa   975  instant    24   pf  regular_ll
# 50            isobaricInhPa  1000  instant    24   pf  regular_ll
# 51            isobaricInhPa   100  instant    24   pf  regular_ll
# 52            isobaricInhPa   200  instant    24   pf  regular_ll
# 53            isobaricInhPa   300  instant    24   pf  regular_ll
# 54            isobaricInhPa   400  instant    24   pf  regular_ll
# 55            isobaricInhPa   500  instant    24   pf  regular_ll
# 56            isobaricInhPa   550  instant    24   pf  regular_ll
# 57            isobaricInhPa   600  instant    24   pf  regular_ll
# 58            isobaricInhPa   650  instant    24   pf  regular_ll
# 59            isobaricInhPa   700  instant    24   pf  regular_ll
# 60            isobaricInhPa   750  instant    24   pf  regular_ll
# 61            isobaricInhPa   800  instant    24   pf  regular_ll
# 62            isobaricInhPa   850  instant    24   pf  regular_ll
# 63            isobaricInhPa   900  instant    24   pf  regular_ll
# 64            isobaricInhPa   925  instant    24   pf  regular_ll
# 65            isobaricInhPa   950  instant    24   pf  regular_ll
# 66            isobaricInhPa   975  instant    24   pf  regular_ll
# 67            isobaricInhPa  1000  instant    24   pf  regular_ll
# 68            isobaricInhPa   100  instant    24   pf  regular_ll
# 69            isobaricInhPa   200  instant    24   pf  regular_ll
# 70            isobaricInhPa   300  instant    24   pf  regular_ll
# 71            isobaricInhPa   400  instant    24   pf  regular_ll
# 72            isobaricInhPa   500  instant    24   pf  regular_ll
# 73            isobaricInhPa   550  instant    24   pf  regular_ll
# 74            isobaricInhPa   600  instant    24   pf  regular_ll
# 75            isobaricInhPa   650  instant    24   pf  regular_ll
# 76            isobaricInhPa   700  instant    24   pf  regular_ll
# 77            isobaricInhPa   750  instant    24   pf  regular_ll
# 78            isobaricInhPa   800  instant    24   pf  regular_ll
# 79            isobaricInhPa   850  instant    24   pf  regular_ll
# 80            isobaricInhPa   900  instant    24   pf  regular_ll
# 81            isobaricInhPa   925  instant    24   pf  regular_ll
# 82            isobaricInhPa   950  instant    24   pf  regular_ll
# 83            isobaricInhPa   975  instant    24   pf  regular_ll
# 84            isobaricInhPa  1000  instant    24   pf  regular_ll
# 85        heightAboveGround    10  instant    24   pf  regular_ll
# 86        heightAboveGround    10  instant    24   pf  regular_ll
# 87        heightAboveGround     2  instant    24   pf  regular_ll
# 88                  meanSea     0  instant    24   pf  regular_ll
# 89                  surface     0  instant    24   pf  regular_ll
# 90        heightAboveGround     2  instant    24   pf  regular_ll
# 91                  surface     0  instant    24   pf  regular_ll
# 92                  surface     0    accum  0-24   pf  regular_ll
# 93                  surface     0    accum  0-24   pf  regular_ll
# 94                  surface     0    accum  0-24   pf  regular_ll
# 95                  surface     0    accum  0-24   pf  regular_ll
# 96         entireAtmosphere     0  instant    24   pf  regular_ll
# 97         entireAtmosphere     0  instant    24   pf  regular_ll
# 98         entireAtmosphere     0  instant    24   pf  regular_ll
# 99         entireAtmosphere     0  instant    24   pf  regular_ll
# 100                 meanSea     0  instant    24   pf  regular_ll
# 101                 surface     0  instant    24   pf  regular_ll
# 102                 surface     0  instant    24   pf  regular_ll
# 103                 surface     0  instant    24   pf  regular_ll
# 104  heightAboveGroundLayer  1000  instant    24   pf  regular_ll
# 105  heightAboveGroundLayer  3000  instant    24   pf  regular_ll
# 106  heightAboveGroundLayer  6000  instant    24   pf  regular_ll
# 107                 surface     0  instant    24   pf  regular_ll
# 108                 surface     0  instant    24   pf  regular_ll
# 109                 surface     0  instant    24   pf  regular_ll
# 110              atmosphere     0  instant    24   pf  regular_ll
# 111           isobaricInhPa   100  instant    24   pf  regular_ll
# 112           isobaricInhPa   200  instant    24   pf  regular_ll
# 113           isobaricInhPa   300  instant    24   pf  regular_ll
# 114           isobaricInhPa   400  instant    24   pf  regular_ll
# 115           isobaricInhPa   500  instant    24   pf  regular_ll
# 116           isobaricInhPa   550  instant    24   pf  regular_ll
# 117           isobaricInhPa   600  instant    24   pf  regular_ll
# 118           isobaricInhPa   650  instant    24   pf  regular_ll
# 119           isobaricInhPa   700  instant    24   pf  regular_ll
# 120           isobaricInhPa   750  instant    24   pf  regular_ll
# 121           isobaricInhPa   800  instant    24   pf  regular_ll
# 122           isobaricInhPa   850  instant    24   pf  regular_ll
# 123           isobaricInhPa   900  instant    24   pf  regular_ll
# 124           isobaricInhPa   925  instant    24   pf  regular_ll
# 125           isobaricInhPa   950  instant    24   pf  regular_ll
# 126           isobaricInhPa   975  instant    24   pf  regular_ll
# 127           isobaricInhPa  1000  instant    24   pf  regular_ll
# 128       heightAboveGround    10  instant    24   pf  regular_ll
# 129                 surface     0  instant    24   pf  regular_ll
