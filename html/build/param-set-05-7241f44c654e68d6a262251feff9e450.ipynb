# %% [markdown]
# # MESO-3KM要素清单：337-525

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file

# %%
from data_notebook.data import get_data_file

meso3km_grib2_orig_file_path = get_data_file("cma-meso-3km")
meso3km_grib2_orig_file_path

# %% [markdown]
# ## 等压面：散度/涡度/平流/水汽通量/露点/假相当位温

# %% [markdown]
# ### 层次
#
# 21 层列表（百帕 (hPa)）：
#
# - 1000
# - 975
# - 950
# - 925
# - 900
# - 850
# - 800
# - 750
# - 700
# - 650
# - 600
# - 550
# - 500
# - 450
# - 400
# - 350
# - 300
# - 250
# - 200
# - 150
# - 100

# %% [markdown]
# ### 散度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 337-357 | div | RELD | d | (0, 2, 13) | s-1 | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RELD",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 337

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="d",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 345

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="div",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 354

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 13},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 357

# %% [markdown]
# ### 涡度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 358-378 | vor | RELV | vo | (0, 2, 12) | s-1 | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="RELV",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 358

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="vo",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 366

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="vor",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 375

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 12},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 378

# %% [markdown]
# ### 温度平流

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 379-399 | tadv |  | unknown | (0, 0, 224) | 1.e-6 k/s | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="tadv",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 379

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 224},
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 387

# %% [markdown]
# ### 涡度平流

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 400-420 | voradv |  | unknown | (0, 2, 224) | 1.e-11/(s2) | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="voradv",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 400

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 224},
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 408

# %% [markdown]
# ### 水汽通量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 421-441 | qflx |  | unknown | (0, 1, 224) | 1e-1.g/(cm.hpa.s) | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qflx",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 421

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 224},
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 429

# %% [markdown]
# ### 水汽通量散度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 442-462 | qdiv | FRZR | unknown | (0, 1, 225) | 1e-7.g/(cm2.hpa.s) | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="FRZR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 442

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="qdiv",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 450

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 225},
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 459

# %% [markdown]
# ### 露点温度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 463-483 | td | DPT | dpt | (0, 0, 6) | K | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DPT",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 463

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="dpt",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 471

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="td",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 480

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 6},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 483

# %% [markdown]
# ### 温度露点差

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 484-504 | ttd | DEPR | unknown | (0, 0, 7) | K | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="DEPR",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 484

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="ttd",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 492

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 7},
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 501

# %% [markdown]
# ### 假相当位温

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 505-525 | thetaSe | EPOT | papt | (0, 0, 3) | K | isobaricInhPa | 21层 | instant | 24 | fc | regular_ll |

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="EPOT",
    level_type="pl",
    level=1000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 505

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="papt",
    level_type="pl",
    level=700,
    lazy=True
)
assert field.attrs["GRIB_count"] == 513

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter="thetaSe",
    level_type="pl",
    level=250,
    lazy=True
)
assert field.attrs["GRIB_count"] == 522

# %%
field = load_field_from_file(
    meso3km_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 0, "parameterNumber": 3},
    level_type="pl",
    level=100,
    lazy=True
)
assert field.attrs["GRIB_count"] == 525
