# %% [markdown]
# # CMA-GFS

# %% [markdown]
# CMA-GFS 基础 GRIB2 数据文件有 861 个要素场。

# %%
import pandas as pd

# %%
from data_notebook.data import get_data_file

gfs_grib2_orig_file_path = get_data_file("cma-gfs")
gfs_grib2_orig_file_path
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-gfs/grib2/orig/Z_NAFP_C_BABJ_20260725000000_P_NWPC-GRAPES-GFS-GLB-02400.grib2')

# %% [markdown]
# ## 要素列表
#
# 使用 reki 识别全部 GRIB2 消息头中的要素，并结合内置要素注册表生成要素列表。

# %%
from IPython.display import display
from data_notebook import get_grib2_inventory

gfs_inventory = get_grib2_inventory(gfs_grib2_orig_file_path)
with pd.option_context("display.max_rows", None):
    display(gfs_inventory)
# Out:
#       序号          要素名   wgrib2    eccodes                  单位  \
# 0      1        rainc    ACPCP      acpcp                  mm
# 1      2       rainnc    NCPCP      ncpcp                  mm
# 2      3         rain     APCP    unknown                  mm
# 3      4           sf    ASNOW    unknown                   m
# 4      5           ts      TMP          t                   K
# 5      6          glw    NLWRF        str                w/m2
# 6      7          gsw    NSWRF        ssr                w/m2
# 7      8         sshf    HFLUX      hflux               ws/m2
# 8      9         slhf    LHTFL       slhf               ws/m2
# 9     10         gulw    ULWRF      ulwrf                w/m2
# 10    11         tulw    ULWRF      ulwrf                w/m2
# 11    12        gdlwc  DLWRFCS      strdc                w/m2
# 12    13        gulwc      NaN    unknown                w/m2
# 13    14        tulwc      NaN    unknown                w/m2
# 14    15         gusw    USWRF      uswrf                w/m2
# 15    16          tsw    NSWRF        tsr                w/m2
# 16    17         tusw    USWRF      uswrf                w/m2
# 17    18         gswc  NSWRFCS       ssrc                w/m2
# 18    19        guswc  USWRFCS  auswrf_cs              w/m2 S
# 19    20         tswc  NSWRFCS       tsrc                w/m2
# 20    21        tuswc  USWRFCS   uswrf_cs              w/m2 S
# 21    22          znt      NaN    unknown                   m
# 22    23           zs      HGT       orog                 Gpm
# 23    24          q2m     SPFH        2sh               kg/kg
# 24    25          t2m      TMP         2t                   K
# 25    26         u10m     UGRD        10u                 m/s
# 26    27         v10m     VGRD        10v                 m/s
# 27    28          tcc     TCDC        tcc                   %
# 28    29          lcc     LCDC        lcc                   %
# 29    30          mcc     MCDC        mcc                   %
# 30    31          hcc     HCDC        hcc                   %
# 31    32          tvw    TCIWV    unknown               kg/m2
# 32    33          tcw    TCOLW    unknown               kg/m2
# 33    34          tiw    TCOLI    unknown               kg/m2
# 34    35         pblh     HPBL        blh                   m
# 35    36         wess      NaN    unknown                N/m2
# 36    37         nsss      NaN    unknown                N/m2
# 37    38           sd     SNOD        sde                   m
# 38    39       albedo    ALBDO         al                   %
# 39    40         mx2t     TMAX       tmax                   K
# 40    41         mn2t     TMIN       tmin                   K
# 41    42      rhmax2m      NaN    unknown                   %
# 42    43      rhmin2m      NaN    unknown                   %
# 43    44           ps     PRES         sp                  Pa
# 44    45          psl    PRMSL      prmsl                  Pa
# 45    46            u     UGRD          u                 m/s
# 46    47            u     UGRD          u                 m/s
# 47    48            u     UGRD          u                 m/s
# 48    49            u     UGRD       100u                 m/s
# 49    50            u     UGRD          u                 m/s
# 50    51            u     UGRD          u                 m/s
# 51    52            u     UGRD          u                 m/s
# 52    53            u     UGRD          u                 m/s
# 53    54            u     UGRD       200u                 m/s
# 54    55            v     VGRD          v                 m/s
# 55    56            v     VGRD          v                 m/s
# 56    57            v     VGRD          v                 m/s
# 57    58            v     VGRD       100v                 m/s
# 58    59            v     VGRD          v                 m/s
# 59    60            v     VGRD          v                 m/s
# 60    61            v     VGRD          v                 m/s
# 61    62            v     VGRD          v                 m/s
# 62    63            v     VGRD       200v                 m/s
# 63    64            h      HGT         gh                 Gpm
# 64    65            h      HGT         gh                 Gpm
# 65    66            h      HGT         gh                 Gpm
# 66    67            h      HGT         gh                 Gpm
# 67    68            h      HGT         gh                 Gpm
# 68    69            h      HGT         gh                 Gpm
# 69    70            h      HGT         gh                 Gpm
# 70    71            h      HGT         gh                 Gpm
# 71    72            h      HGT         gh                 Gpm
# 72    73            h      HGT         gh                 Gpm
# 73    74            h      HGT         gh                 Gpm
# 74    75            h      HGT         gh                 Gpm
# 75    76            h      HGT         gh                 Gpm
# 76    77            h      HGT         gh                 Gpm
# 77    78            h      HGT         gh                 Gpm
# 78    79            h      HGT         gh                 Gpm
# 79    80            h      HGT         gh                 Gpm
# 80    81            h      HGT         gh                 Gpm
# 81    82            h      HGT         gh                 Gpm
# 82    83            h      HGT         gh                 Gpm
# 83    84            h      HGT         gh                 Gpm
# 84    85            h      HGT         gh                 Gpm
# 85    86            h      HGT         gh                 Gpm
# 86    87            h      HGT         gh                 Gpm
# 87    88            h      HGT         gh                 Gpm
# 88    89            h      HGT         gh                 Gpm
# 89    90            h      HGT         gh                 Gpm
# 90    91            h      HGT         gh                 Gpm
# 91    92            h      HGT         gh                 Gpm
# 92    93            h      HGT         gh                 Gpm
# 93    94            h      HGT         gh                 Gpm
# 94    95            h      HGT         gh                 Gpm
# 95    96            h      HGT         gh                 Gpm
# 96    97            h      HGT         gh                 Gpm
# 97    98            h      HGT         gh                 Gpm
# 98    99            h      HGT         gh                 Gpm
# 99   100            h      HGT         gh                 Gpm
# 100  101            h      HGT         gh                 Gpm
# 101  102            h      HGT         gh                 Gpm
# 102  103            h      HGT         gh                 Gpm
# 103  104            t      TMP          t                   K
# 104  105            t      TMP          t                   K
# 105  106            t      TMP          t                   K
# 106  107            t      TMP          t                   K
# 107  108            t      TMP          t                   K
# 108  109            t      TMP          t                   K
# 109  110            t      TMP          t                   K
# 110  111            t      TMP          t                   K
# 111  112            t      TMP          t                   K
# 112  113            t      TMP          t                   K
# 113  114            t      TMP          t                   K
# 114  115            t      TMP          t                   K
# 115  116            t      TMP          t                   K
# 116  117            t      TMP          t                   K
# 117  118            t      TMP          t                   K
# 118  119            t      TMP          t                   K
# 119  120            t      TMP          t                   K
# 120  121            t      TMP          t                   K
# 121  122            t      TMP          t                   K
# 122  123            t      TMP          t                   K
# 123  124            t      TMP          t                   K
# 124  125            t      TMP          t                   K
# 125  126            t      TMP          t                   K
# 126  127            t      TMP          t                   K
# 127  128            t      TMP          t                   K
# 128  129            t      TMP          t                   K
# 129  130            t      TMP          t                   K
# 130  131            t      TMP          t                   K
# 131  132            t      TMP          t                   K
# 132  133            t      TMP          t                   K
# 133  134            t      TMP          t                   K
# 134  135            t      TMP          t                   K
# 135  136            t      TMP          t                   K
# 136  137            t      TMP          t                   K
# 137  138            t      TMP          t                   K
# 138  139            t      TMP          t                   K
# 139  140            t      TMP          t                   K
# 140  141            t      TMP          t                   K
# 141  142            t      TMP          t                   K
# 142  143            t      TMP          t                   K
# 143  144            u     UGRD          u                 m/s
# 144  145            u     UGRD          u                 m/s
# 145  146            u     UGRD          u                 m/s
# 146  147            u     UGRD          u                 m/s
# 147  148            u     UGRD          u                 m/s
# 148  149            u     UGRD          u                 m/s
# 149  150            u     UGRD          u                 m/s
# 150  151            u     UGRD          u                 m/s
# 151  152            u     UGRD          u                 m/s
# 152  153            u     UGRD          u                 m/s
# 153  154            u     UGRD          u                 m/s
# 154  155            u     UGRD          u                 m/s
# 155  156            u     UGRD          u                 m/s
# 156  157            u     UGRD          u                 m/s
# 157  158            u     UGRD          u                 m/s
# 158  159            u     UGRD          u                 m/s
# 159  160            u     UGRD          u                 m/s
# 160  161            u     UGRD          u                 m/s
# 161  162            u     UGRD          u                 m/s
# 162  163            u     UGRD          u                 m/s
# 163  164            u     UGRD          u                 m/s
# 164  165            u     UGRD          u                 m/s
# 165  166            u     UGRD          u                 m/s
# 166  167            u     UGRD          u                 m/s
# 167  168            u     UGRD          u                 m/s
# 168  169            u     UGRD          u                 m/s
# 169  170            u     UGRD          u                 m/s
# 170  171            u     UGRD          u                 m/s
# 171  172            u     UGRD          u                 m/s
# 172  173            u     UGRD          u                 m/s
# 173  174            u     UGRD          u                 m/s
# 174  175            u     UGRD          u                 m/s
# 175  176            u     UGRD          u                 m/s
# 176  177            u     UGRD          u                 m/s
# 177  178            u     UGRD          u                 m/s
# 178  179            u     UGRD          u                 m/s
# 179  180            u     UGRD          u                 m/s
# 180  181            u     UGRD          u                 m/s
# 181  182            u     UGRD          u                 m/s
# 182  183            u     UGRD          u                 m/s
# 183  184            v     VGRD          v                 m/s
# 184  185            v     VGRD          v                 m/s
# 185  186            v     VGRD          v                 m/s
# 186  187            v     VGRD          v                 m/s
# 187  188            v     VGRD          v                 m/s
# 188  189            v     VGRD          v                 m/s
# 189  190            v     VGRD          v                 m/s
# 190  191            v     VGRD          v                 m/s
# 191  192            v     VGRD          v                 m/s
# 192  193            v     VGRD          v                 m/s
# 193  194            v     VGRD          v                 m/s
# 194  195            v     VGRD          v                 m/s
# 195  196            v     VGRD          v                 m/s
# 196  197            v     VGRD          v                 m/s
# 197  198            v     VGRD          v                 m/s
# 198  199            v     VGRD          v                 m/s
# 199  200            v     VGRD          v                 m/s
# 200  201            v     VGRD          v                 m/s
# 201  202            v     VGRD          v                 m/s
# 202  203            v     VGRD          v                 m/s
# 203  204            v     VGRD          v                 m/s
# 204  205            v     VGRD          v                 m/s
# 205  206            v     VGRD          v                 m/s
# 206  207            v     VGRD          v                 m/s
# 207  208            v     VGRD          v                 m/s
# 208  209            v     VGRD          v                 m/s
# 209  210            v     VGRD          v                 m/s
# 210  211            v     VGRD          v                 m/s
# 211  212            v     VGRD          v                 m/s
# 212  213            v     VGRD          v                 m/s
# 213  214            v     VGRD          v                 m/s
# 214  215            v     VGRD          v                 m/s
# 215  216            v     VGRD          v                 m/s
# 216  217            v     VGRD          v                 m/s
# 217  218            v     VGRD          v                 m/s
# 218  219            v     VGRD          v                 m/s
# 219  220            v     VGRD          v                 m/s
# 220  221            v     VGRD          v                 m/s
# 221  222            v     VGRD          v                 m/s
# 222  223            v     VGRD          v                 m/s
# 223  224            w     DZDT         wz                 m/s
# 224  225            w     DZDT         wz                 m/s
# 225  226            w     DZDT         wz                 m/s
# 226  227            w     DZDT         wz                 m/s
# 227  228            w     DZDT         wz                 m/s
# 228  229            w     DZDT         wz                 m/s
# 229  230            w     DZDT         wz                 m/s
# 230  231            w     DZDT         wz                 m/s
# 231  232            w     DZDT         wz                 m/s
# 232  233            w     DZDT         wz                 m/s
# 233  234            w     DZDT         wz                 m/s
# 234  235            w     DZDT         wz                 m/s
# 235  236            w     DZDT         wz                 m/s
# 236  237            w     DZDT         wz                 m/s
# 237  238            w     DZDT         wz                 m/s
# 238  239            w     DZDT         wz                 m/s
# 239  240            w     DZDT         wz                 m/s
# 240  241            w     DZDT         wz                 m/s
# 241  242            w     DZDT         wz                 m/s
# 242  243            w     DZDT         wz                 m/s
# 243  244            w     DZDT         wz                 m/s
# 244  245            w     DZDT         wz                 m/s
# 245  246            w     DZDT         wz                 m/s
# 246  247            w     DZDT         wz                 m/s
# 247  248            w     DZDT         wz                 m/s
# 248  249            w     DZDT         wz                 m/s
# 249  250            w     DZDT         wz                 m/s
# 250  251            w     DZDT         wz                 m/s
# 251  252            w     DZDT         wz                 m/s
# 252  253            w     DZDT         wz                 m/s
# 253  254            q     SPFH          q               kg/kg
# 254  255            q     SPFH          q               kg/kg
# 255  256            q     SPFH          q               kg/kg
# 256  257            q     SPFH          q               kg/kg
# 257  258            q     SPFH          q               kg/kg
# 258  259            q     SPFH          q               kg/kg
# 259  260            q     SPFH          q               kg/kg
# 260  261            q     SPFH          q               kg/kg
# 261  262            q     SPFH          q               kg/kg
# 262  263            q     SPFH          q               kg/kg
# 263  264            q     SPFH          q               kg/kg
# 264  265            q     SPFH          q               kg/kg
# 265  266            q     SPFH          q               kg/kg
# 266  267            q     SPFH          q               kg/kg
# 267  268            q     SPFH          q               kg/kg
# 268  269            q     SPFH          q               kg/kg
# 269  270            q     SPFH          q               kg/kg
# 270  271            q     SPFH          q               kg/kg
# 271  272            q     SPFH          q               kg/kg
# 272  273            q     SPFH          q               kg/kg
# 273  274            q     SPFH          q               kg/kg
# 274  275            q     SPFH          q               kg/kg
# 275  276            q     SPFH          q               kg/kg
# 276  277            q     SPFH          q               kg/kg
# 277  278            q     SPFH          q               kg/kg
# 278  279            q     SPFH          q               kg/kg
# 279  280            q     SPFH          q               kg/kg
# 280  281            q     SPFH          q               kg/kg
# 281  282            q     SPFH          q               kg/kg
# 282  283            q     SPFH          q               kg/kg
# 283  284           qc     CLMR      clwmr               kg/kg
# 284  285           qc     CLMR      clwmr               kg/kg
# 285  286           qc     CLMR      clwmr               kg/kg
# 286  287           qc     CLMR      clwmr               kg/kg
# 287  288           qc     CLMR      clwmr               kg/kg
# 288  289           qc     CLMR      clwmr               kg/kg
# 289  290           qc     CLMR      clwmr               kg/kg
# 290  291           qc     CLMR      clwmr               kg/kg
# 291  292           qc     CLMR      clwmr               kg/kg
# 292  293           qc     CLMR      clwmr               kg/kg
# 293  294           qc     CLMR      clwmr               kg/kg
# 294  295           qc     CLMR      clwmr               kg/kg
# 295  296           qc     CLMR      clwmr               kg/kg
# 296  297           qc     CLMR      clwmr               kg/kg
# 297  298           qc     CLMR      clwmr               kg/kg
# 298  299           qc     CLMR      clwmr               kg/kg
# 299  300           qc     CLMR      clwmr               kg/kg
# 300  301           qc     CLMR      clwmr               kg/kg
# 301  302           qc     CLMR      clwmr               kg/kg
# 302  303           qc     CLMR      clwmr               kg/kg
# 303  304           qc     CLMR      clwmr               kg/kg
# 304  305           qc     CLMR      clwmr               kg/kg
# 305  306           qc     CLMR      clwmr               kg/kg
# 306  307           qc     CLMR      clwmr               kg/kg
# 307  308           qc     CLMR      clwmr               kg/kg
# 308  309           qc     CLMR      clwmr               kg/kg
# 309  310           qc     CLMR      clwmr               kg/kg
# 310  311           qc     CLMR      clwmr               kg/kg
# 311  312           qc     CLMR      clwmr               kg/kg
# 312  313           qc     CLMR      clwmr               kg/kg
# 313  314           qr     RWMR       rwmr               kg/kg
# 314  315           qr     RWMR       rwmr               kg/kg
# 315  316           qr     RWMR       rwmr               kg/kg
# 316  317           qr     RWMR       rwmr               kg/kg
# 317  318           qr     RWMR       rwmr               kg/kg
# 318  319           qr     RWMR       rwmr               kg/kg
# 319  320           qr     RWMR       rwmr               kg/kg
# 320  321           qr     RWMR       rwmr               kg/kg
# 321  322           qr     RWMR       rwmr               kg/kg
# 322  323           qr     RWMR       rwmr               kg/kg
# 323  324           qr     RWMR       rwmr               kg/kg
# 324  325           qr     RWMR       rwmr               kg/kg
# 325  326           qr     RWMR       rwmr               kg/kg
# 326  327           qr     RWMR       rwmr               kg/kg
# 327  328           qr     RWMR       rwmr               kg/kg
# 328  329           qr     RWMR       rwmr               kg/kg
# 329  330           qr     RWMR       rwmr               kg/kg
# 330  331           qr     RWMR       rwmr               kg/kg
# 331  332           qr     RWMR       rwmr               kg/kg
# 332  333           qr     RWMR       rwmr               kg/kg
# 333  334           qr     RWMR       rwmr               kg/kg
# 334  335           qr     RWMR       rwmr               kg/kg
# 335  336           qr     RWMR       rwmr               kg/kg
# 336  337           qr     RWMR       rwmr               kg/kg
# 337  338           qr     RWMR       rwmr               kg/kg
# 338  339           qr     RWMR       rwmr               kg/kg
# 339  340           qr     RWMR       rwmr               kg/kg
# 340  341           qr     RWMR       rwmr               kg/kg
# 341  342           qr     RWMR       rwmr               kg/kg
# 342  343           qr     RWMR       rwmr               kg/kg
# 343  344           qi     ICMR       icmr               kg/kg
# 344  345           qi     ICMR       icmr               kg/kg
# 345  346           qi     ICMR       icmr               kg/kg
# 346  347           qi     ICMR       icmr               kg/kg
# 347  348           qi     ICMR       icmr               kg/kg
# 348  349           qi     ICMR       icmr               kg/kg
# 349  350           qi     ICMR       icmr               kg/kg
# 350  351           qi     ICMR       icmr               kg/kg
# 351  352           qi     ICMR       icmr               kg/kg
# 352  353           qi     ICMR       icmr               kg/kg
# 353  354           qi     ICMR       icmr               kg/kg
# 354  355           qi     ICMR       icmr               kg/kg
# 355  356           qi     ICMR       icmr               kg/kg
# 356  357           qi     ICMR       icmr               kg/kg
# 357  358           qi     ICMR       icmr               kg/kg
# 358  359           qi     ICMR       icmr               kg/kg
# 359  360           qi     ICMR       icmr               kg/kg
# 360  361           qi     ICMR       icmr               kg/kg
# 361  362           qi     ICMR       icmr               kg/kg
# 362  363           qi     ICMR       icmr               kg/kg
# 363  364           qi     ICMR       icmr               kg/kg
# 364  365           qi     ICMR       icmr               kg/kg
# 365  366           qi     ICMR       icmr               kg/kg
# 366  367           qi     ICMR       icmr               kg/kg
# 367  368           qi     ICMR       icmr               kg/kg
# 368  369           qi     ICMR       icmr               kg/kg
# 369  370           qi     ICMR       icmr               kg/kg
# 370  371           qi     ICMR       icmr               kg/kg
# 371  372           qi     ICMR       icmr               kg/kg
# 372  373           qi     ICMR       icmr               kg/kg
# 373  374           qs     SNMR       snmr               kg/kg
# 374  375           qs     SNMR       snmr               kg/kg
# 375  376           qs     SNMR       snmr               kg/kg
# 376  377           qs     SNMR       snmr               kg/kg
# 377  378           qs     SNMR       snmr               kg/kg
# 378  379           qs     SNMR       snmr               kg/kg
# 379  380           qs     SNMR       snmr               kg/kg
# 380  381           qs     SNMR       snmr               kg/kg
# 381  382           qs     SNMR       snmr               kg/kg
# 382  383           qs     SNMR       snmr               kg/kg
# 383  384           qs     SNMR       snmr               kg/kg
# 384  385           qs     SNMR       snmr               kg/kg
# 385  386           qs     SNMR       snmr               kg/kg
# 386  387           qs     SNMR       snmr               kg/kg
# 387  388           qs     SNMR       snmr               kg/kg
# 388  389           qs     SNMR       snmr               kg/kg
# 389  390           qs     SNMR       snmr               kg/kg
# 390  391           qs     SNMR       snmr               kg/kg
# 391  392           qs     SNMR       snmr               kg/kg
# 392  393           qs     SNMR       snmr               kg/kg
# 393  394           qs     SNMR       snmr               kg/kg
# 394  395           qs     SNMR       snmr               kg/kg
# 395  396           qs     SNMR       snmr               kg/kg
# 396  397           qs     SNMR       snmr               kg/kg
# 397  398           qs     SNMR       snmr               kg/kg
# 398  399           qs     SNMR       snmr               kg/kg
# 399  400           qs     SNMR       snmr               kg/kg
# 400  401           qs     SNMR       snmr               kg/kg
# 401  402           qs     SNMR       snmr               kg/kg
# 402  403           qs     SNMR       snmr               kg/kg
# 403  404      graupel     GRLE       grle               kg/kg
# 404  405      graupel     GRLE       grle               kg/kg
# 405  406      graupel     GRLE       grle               kg/kg
# 406  407      graupel     GRLE       grle               kg/kg
# 407  408      graupel     GRLE       grle               kg/kg
# 408  409      graupel     GRLE       grle               kg/kg
# 409  410      graupel     GRLE       grle               kg/kg
# 410  411      graupel     GRLE       grle               kg/kg
# 411  412      graupel     GRLE       grle               kg/kg
# 412  413      graupel     GRLE       grle               kg/kg
# 413  414      graupel     GRLE       grle               kg/kg
# 414  415      graupel     GRLE       grle               kg/kg
# 415  416      graupel     GRLE       grle               kg/kg
# 416  417      graupel     GRLE       grle               kg/kg
# 417  418      graupel     GRLE       grle               kg/kg
# 418  419      graupel     GRLE       grle               kg/kg
# 419  420      graupel     GRLE       grle               kg/kg
# 420  421      graupel     GRLE       grle               kg/kg
# 421  422      graupel     GRLE       grle               kg/kg
# 422  423      graupel     GRLE       grle               kg/kg
# 423  424      graupel     GRLE       grle               kg/kg
# 424  425      graupel     GRLE       grle               kg/kg
# 425  426      graupel     GRLE       grle               kg/kg
# 426  427      graupel     GRLE       grle               kg/kg
# 427  428      graupel     GRLE       grle               kg/kg
# 428  429      graupel     GRLE       grle               kg/kg
# 429  430      graupel     GRLE       grle               kg/kg
# 430  431      graupel     GRLE       grle               kg/kg
# 431  432      graupel     GRLE       grle               kg/kg
# 432  433      graupel     GRLE       grle               kg/kg
# 433  434           cc     CDCC        ccl                   %
# 434  435           cc     CDCC        ccl                   %
# 435  436           cc     CDCC        ccl                   %
# 436  437           cc     CDCC        ccl                   %
# 437  438           cc     CDCC        ccl                   %
# 438  439           cc     CDCC        ccl                   %
# 439  440           cc     CDCC        ccl                   %
# 440  441           cc     CDCC        ccl                   %
# 441  442           cc     CDCC        ccl                   %
# 442  443           cc     CDCC        ccl                   %
# 443  444           cc     CDCC        ccl                   %
# 444  445           cc     CDCC        ccl                   %
# 445  446           cc     CDCC        ccl                   %
# 446  447           cc     CDCC        ccl                   %
# 447  448           cc     CDCC        ccl                   %
# 448  449           cc     CDCC        ccl                   %
# 449  450           cc     CDCC        ccl                   %
# 450  451           cc     CDCC        ccl                   %
# 451  452           cc     CDCC        ccl                   %
# 452  453           cc     CDCC        ccl                   %
# 453  454           cc     CDCC        ccl                   %
# 454  455           cc     CDCC        ccl                   %
# 455  456           cc     CDCC        ccl                   %
# 456  457           cc     CDCC        ccl                   %
# 457  458           cc     CDCC        ccl                   %
# 458  459           cc     CDCC        ccl                   %
# 459  460           cc     CDCC        ccl                   %
# 460  461           cc     CDCC        ccl                   %
# 461  462           cc     CDCC        ccl                   %
# 462  463           cc     CDCC        ccl                   %
# 463  464     st(0-10)      TMP          t                   K
# 464  465    st(10-40)      TMP          t                   K
# 465  466   st(40-100)      TMP          t                   K
# 466  467  st(100-200)      TMP          t                   K
# 467  468     sw(0-10)     SPFH          q               kg/kg
# 468  469    sw(10-40)     SPFH          q               kg/kg
# 469  470   sw(40-100)     SPFH          q               kg/kg
# 470  471  sw(100-200)     SPFH          q               kg/kg
# 471  472           rh       RH          r                   %
# 472  473           rh       RH          r                   %
# 473  474           rh       RH          r                   %
# 474  475           rh       RH          r                   %
# 475  476           rh       RH          r                   %
# 476  477           rh       RH          r                   %
# 477  478           rh       RH          r                   %
# 478  479           rh       RH          r                   %
# 479  480           rh       RH          r                   %
# 480  481           rh       RH          r                   %
# 481  482           rh       RH          r                   %
# 482  483           rh       RH          r                   %
# 483  484           rh       RH          r                   %
# 484  485           rh       RH          r                   %
# 485  486           rh       RH          r                   %
# 486  487           rh       RH          r                   %
# 487  488           rh       RH          r                   %
# 488  489           rh       RH          r                   %
# 489  490           rh       RH          r                   %
# 490  491           rh       RH          r                   %
# 491  492           rh       RH          r                   %
# 492  493           rh       RH          r                   %
# 493  494           rh       RH          r                   %
# 494  495           rh       RH          r                   %
# 495  496           rh       RH          r                   %
# 496  497           rh       RH          r                   %
# 497  498           rh       RH          r                   %
# 498  499           rh       RH          r                   %
# 499  500           rh       RH          r                   %
# 500  501           rh       RH          r                   %
# 501  502         rh2m       RH         2r                   %
# 502  503         td2m      DPT         2d                   K
# 503  504          div     RELD          d                 s-1
# 504  505          div     RELD          d                 s-1
# 505  506          div     RELD          d                 s-1
# 506  507          div     RELD          d                 s-1
# 507  508          div     RELD          d                 s-1
# 508  509          div     RELD          d                 s-1
# 509  510          div     RELD          d                 s-1
# 510  511          div     RELD          d                 s-1
# 511  512          div     RELD          d                 s-1
# 512  513          div     RELD          d                 s-1
# 513  514          div     RELD          d                 s-1
# 514  515          div     RELD          d                 s-1
# 515  516          div     RELD          d                 s-1
# 516  517          div     RELD          d                 s-1
# 517  518          div     RELD          d                 s-1
# 518  519          div     RELD          d                 s-1
# 519  520          div     RELD          d                 s-1
# 520  521          div     RELD          d                 s-1
# 521  522          div     RELD          d                 s-1
# 522  523          div     RELD          d                 s-1
# 523  524          div     RELD          d                 s-1
# 524  525          div     RELD          d                 s-1
# 525  526          div     RELD          d                 s-1
# 526  527          div     RELD          d                 s-1
# 527  528          div     RELD          d                 s-1
# 528  529          div     RELD          d                 s-1
# 529  530          div     RELD          d                 s-1
# 530  531          div     RELD          d                 s-1
# 531  532          div     RELD          d                 s-1
# 532  533          div     RELD          d                 s-1
# 533  534          vor     RELV         vo                 s-1
# 534  535          vor     RELV         vo                 s-1
# 535  536          vor     RELV         vo                 s-1
# 536  537          vor     RELV         vo                 s-1
# 537  538          vor     RELV         vo                 s-1
# 538  539          vor     RELV         vo                 s-1
# 539  540          vor     RELV         vo                 s-1
# 540  541          vor     RELV         vo                 s-1
# 541  542          vor     RELV         vo                 s-1
# 542  543          vor     RELV         vo                 s-1
# 543  544          vor     RELV         vo                 s-1
# 544  545          vor     RELV         vo                 s-1
# 545  546          vor     RELV         vo                 s-1
# 546  547          vor     RELV         vo                 s-1
# 547  548          vor     RELV         vo                 s-1
# 548  549          vor     RELV         vo                 s-1
# 549  550          vor     RELV         vo                 s-1
# 550  551          vor     RELV         vo                 s-1
# 551  552          vor     RELV         vo                 s-1
# 552  553          vor     RELV         vo                 s-1
# 553  554          vor     RELV         vo                 s-1
# 554  555          vor     RELV         vo                 s-1
# 555  556          vor     RELV         vo                 s-1
# 556  557          vor     RELV         vo                 s-1
# 557  558          vor     RELV         vo                 s-1
# 558  559          vor     RELV         vo                 s-1
# 559  560          vor     RELV         vo                 s-1
# 560  561          vor     RELV         vo                 s-1
# 561  562          vor     RELV         vo                 s-1
# 562  563          vor     RELV         vo                 s-1
# 563  564         tadv      NaN    unknown           1.e-6 k/s
# 564  565         tadv      NaN    unknown           1.e-6 k/s
# 565  566         tadv      NaN    unknown           1.e-6 k/s
# 566  567         tadv      NaN    unknown           1.e-6 k/s
# 567  568         tadv      NaN    unknown           1.e-6 k/s
# 568  569         tadv      NaN    unknown           1.e-6 k/s
# 569  570         tadv      NaN    unknown           1.e-6 k/s
# 570  571         tadv      NaN    unknown           1.e-6 k/s
# 571  572         tadv      NaN    unknown           1.e-6 k/s
# 572  573         tadv      NaN    unknown           1.e-6 k/s
# 573  574         tadv      NaN    unknown           1.e-6 k/s
# 574  575         tadv      NaN    unknown           1.e-6 k/s
# 575  576         tadv      NaN    unknown           1.e-6 k/s
# 576  577         tadv      NaN    unknown           1.e-6 k/s
# 577  578         tadv      NaN    unknown           1.e-6 k/s
# 578  579         tadv      NaN    unknown           1.e-6 k/s
# 579  580         tadv      NaN    unknown           1.e-6 k/s
# 580  581         tadv      NaN    unknown           1.e-6 k/s
# 581  582         tadv      NaN    unknown           1.e-6 k/s
# 582  583         tadv      NaN    unknown           1.e-6 k/s
# 583  584         tadv      NaN    unknown           1.e-6 k/s
# 584  585         tadv      NaN    unknown           1.e-6 k/s
# 585  586         tadv      NaN    unknown           1.e-6 k/s
# 586  587         tadv      NaN    unknown           1.e-6 k/s
# 587  588         tadv      NaN    unknown           1.e-6 k/s
# 588  589         tadv      NaN    unknown           1.e-6 k/s
# 589  590         tadv      NaN    unknown           1.e-6 k/s
# 590  591         tadv      NaN    unknown           1.e-6 k/s
# 591  592         tadv      NaN    unknown           1.e-6 k/s
# 592  593         tadv      NaN    unknown           1.e-6 k/s
# 593  594       voradv      NaN    unknown         1.e-11/(s2)
# 594  595       voradv      NaN    unknown         1.e-11/(s2)
# 595  596       voradv      NaN    unknown         1.e-11/(s2)
# 596  597       voradv      NaN    unknown         1.e-11/(s2)
# 597  598       voradv      NaN    unknown         1.e-11/(s2)
# 598  599       voradv      NaN    unknown         1.e-11/(s2)
# 599  600       voradv      NaN    unknown         1.e-11/(s2)
# 600  601       voradv      NaN    unknown         1.e-11/(s2)
# 601  602       voradv      NaN    unknown         1.e-11/(s2)
# 602  603       voradv      NaN    unknown         1.e-11/(s2)
# 603  604       voradv      NaN    unknown         1.e-11/(s2)
# 604  605       voradv      NaN    unknown         1.e-11/(s2)
# 605  606       voradv      NaN    unknown         1.e-11/(s2)
# 606  607       voradv      NaN    unknown         1.e-11/(s2)
# 607  608       voradv      NaN    unknown         1.e-11/(s2)
# 608  609       voradv      NaN    unknown         1.e-11/(s2)
# 609  610       voradv      NaN    unknown         1.e-11/(s2)
# 610  611       voradv      NaN    unknown         1.e-11/(s2)
# 611  612       voradv      NaN    unknown         1.e-11/(s2)
# 612  613       voradv      NaN    unknown         1.e-11/(s2)
# 613  614       voradv      NaN    unknown         1.e-11/(s2)
# 614  615       voradv      NaN    unknown         1.e-11/(s2)
# 615  616       voradv      NaN    unknown         1.e-11/(s2)
# 616  617       voradv      NaN    unknown         1.e-11/(s2)
# 617  618       voradv      NaN    unknown         1.e-11/(s2)
# 618  619       voradv      NaN    unknown         1.e-11/(s2)
# 619  620       voradv      NaN    unknown         1.e-11/(s2)
# 620  621       voradv      NaN    unknown         1.e-11/(s2)
# 621  622       voradv      NaN    unknown         1.e-11/(s2)
# 622  623       voradv      NaN    unknown         1.e-11/(s2)
# 623  624         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 624  625         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 625  626         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 626  627         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 627  628         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 628  629         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 629  630         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 630  631         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 631  632         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 632  633         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 633  634         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 634  635         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 635  636         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 636  637         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 637  638         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 638  639         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 639  640         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 640  641         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 641  642         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 642  643         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 643  644         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 644  645         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 645  646         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 646  647         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 647  648         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 648  649         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 649  650         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 650  651         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 651  652         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 652  653         qflx      NaN    unknown   1e-1.g/(cm.hpa.s)
# 653  654         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 654  655         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 655  656         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 656  657         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 657  658         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 658  659         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 659  660         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 660  661         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 661  662         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 662  663         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 663  664         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 664  665         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 665  666         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 666  667         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 667  668         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 668  669         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 669  670         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 670  671         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 671  672         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 672  673         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 673  674         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 674  675         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 675  676         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 676  677         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 677  678         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 678  679         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 679  680         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 680  681         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 681  682         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 682  683         qdiv     FRZR    unknown  1e-7.g/(cm2.hpa.s)
# 683  684           td      DPT        dpt                   K
# 684  685           td      DPT        dpt                   K
# 685  686           td      DPT        dpt                   K
# 686  687           td      DPT        dpt                   K
# 687  688           td      DPT        dpt                   K
# 688  689           td      DPT        dpt                   K
# 689  690           td      DPT        dpt                   K
# 690  691           td      DPT        dpt                   K
# 691  692           td      DPT        dpt                   K
# 692  693           td      DPT        dpt                   K
# 693  694           td      DPT        dpt                   K
# 694  695           td      DPT        dpt                   K
# 695  696           td      DPT        dpt                   K
# 696  697           td      DPT        dpt                   K
# 697  698           td      DPT        dpt                   K
# 698  699           td      DPT        dpt                   K
# 699  700           td      DPT        dpt                   K
# 700  701           td      DPT        dpt                   K
# 701  702           td      DPT        dpt                   K
# 702  703           td      DPT        dpt                   K
# 703  704           td      DPT        dpt                   K
# 704  705           td      DPT        dpt                   K
# 705  706           td      DPT        dpt                   K
# 706  707           td      DPT        dpt                   K
# 707  708           td      DPT        dpt                   K
# 708  709           td      DPT        dpt                   K
# 709  710           td      DPT        dpt                   K
# 710  711           td      DPT        dpt                   K
# 711  712           td      DPT        dpt                   K
# 712  713           td      DPT        dpt                   K
# 713  714          ttd     DEPR    unknown                   K
# 714  715          ttd     DEPR    unknown                   K
# 715  716          ttd     DEPR    unknown                   K
# 716  717          ttd     DEPR    unknown                   K
# 717  718          ttd     DEPR    unknown                   K
# 718  719          ttd     DEPR    unknown                   K
# 719  720          ttd     DEPR    unknown                   K
# 720  721          ttd     DEPR    unknown                   K
# 721  722          ttd     DEPR    unknown                   K
# 722  723          ttd     DEPR    unknown                   K
# 723  724          ttd     DEPR    unknown                   K
# 724  725          ttd     DEPR    unknown                   K
# 725  726          ttd     DEPR    unknown                   K
# 726  727          ttd     DEPR    unknown                   K
# 727  728          ttd     DEPR    unknown                   K
# 728  729          ttd     DEPR    unknown                   K
# 729  730          ttd     DEPR    unknown                   K
# 730  731          ttd     DEPR    unknown                   K
# 731  732          ttd     DEPR    unknown                   K
# 732  733          ttd     DEPR    unknown                   K
# 733  734          ttd     DEPR    unknown                   K
# 734  735          ttd     DEPR    unknown                   K
# 735  736          ttd     DEPR    unknown                   K
# 736  737          ttd     DEPR    unknown                   K
# ...
# 626           isobaricInhPa   925  instant    24   fc  regular_ll
# 627           isobaricInhPa   900  instant    24   fc  regular_ll
# 628           isobaricInhPa   850  instant    24   fc  regular_ll
# 629           isobaricInhPa   800  instant    24   fc  regular_ll
# 630           isobaricInhPa   750  instant    24   fc  regular_ll
# 631           isobaricInhPa   700  instant    24   fc  regular_ll
# 632           isobaricInhPa   650  instant    24   fc  regular_ll
# 633           isobaricInhPa   600  instant    24   fc  regular_ll
# 634           isobaricInhPa   550  instant    24   fc  regular_ll
# 635           isobaricInhPa   500  instant    24   fc  regular_ll
# 636           isobaricInhPa   450  instant    24   fc  regular_ll
# 637           isobaricInhPa   400  instant    24   fc  regular_ll
# 638           isobaricInhPa   350  instant    24   fc  regular_ll
# 639           isobaricInhPa   300  instant    24   fc  regular_ll
# 640           isobaricInhPa   275  instant    24   fc  regular_ll
# 641           isobaricInhPa   250  instant    24   fc  regular_ll
# 642           isobaricInhPa   225  instant    24   fc  regular_ll
# 643           isobaricInhPa   200  instant    24   fc  regular_ll
# 644           isobaricInhPa   175  instant    24   fc  regular_ll
# 645           isobaricInhPa   150  instant    24   fc  regular_ll
# 646           isobaricInhPa   125  instant    24   fc  regular_ll
# 647           isobaricInhPa   100  instant    24   fc  regular_ll
# 648           isobaricInhPa    70  instant    24   fc  regular_ll
# 649           isobaricInhPa    50  instant    24   fc  regular_ll
# 650           isobaricInhPa    30  instant    24   fc  regular_ll
# 651           isobaricInhPa    20  instant    24   fc  regular_ll
# 652           isobaricInhPa    10  instant    24   fc  regular_ll
# 653           isobaricInhPa  1000  instant    24   fc  regular_ll
# 654           isobaricInhPa   975  instant    24   fc  regular_ll
# 655           isobaricInhPa   950  instant    24   fc  regular_ll
# 656           isobaricInhPa   925  instant    24   fc  regular_ll
# 657           isobaricInhPa   900  instant    24   fc  regular_ll
# 658           isobaricInhPa   850  instant    24   fc  regular_ll
# 659           isobaricInhPa   800  instant    24   fc  regular_ll
# 660           isobaricInhPa   750  instant    24   fc  regular_ll
# 661           isobaricInhPa   700  instant    24   fc  regular_ll
# 662           isobaricInhPa   650  instant    24   fc  regular_ll
# 663           isobaricInhPa   600  instant    24   fc  regular_ll
# 664           isobaricInhPa   550  instant    24   fc  regular_ll
# 665           isobaricInhPa   500  instant    24   fc  regular_ll
# 666           isobaricInhPa   450  instant    24   fc  regular_ll
# 667           isobaricInhPa   400  instant    24   fc  regular_ll
# 668           isobaricInhPa   350  instant    24   fc  regular_ll
# 669           isobaricInhPa   300  instant    24   fc  regular_ll
# 670           isobaricInhPa   275  instant    24   fc  regular_ll
# 671           isobaricInhPa   250  instant    24   fc  regular_ll
# 672           isobaricInhPa   225  instant    24   fc  regular_ll
# 673           isobaricInhPa   200  instant    24   fc  regular_ll
# 674           isobaricInhPa   175  instant    24   fc  regular_ll
# 675           isobaricInhPa   150  instant    24   fc  regular_ll
# 676           isobaricInhPa   125  instant    24   fc  regular_ll
# 677           isobaricInhPa   100  instant    24   fc  regular_ll
# 678           isobaricInhPa    70  instant    24   fc  regular_ll
# 679           isobaricInhPa    50  instant    24   fc  regular_ll
# 680           isobaricInhPa    30  instant    24   fc  regular_ll
# 681           isobaricInhPa    20  instant    24   fc  regular_ll
# 682           isobaricInhPa    10  instant    24   fc  regular_ll
# 683           isobaricInhPa  1000  instant    24   fc  regular_ll
# 684           isobaricInhPa   975  instant    24   fc  regular_ll
# 685           isobaricInhPa   950  instant    24   fc  regular_ll
# 686           isobaricInhPa   925  instant    24   fc  regular_ll
# 687           isobaricInhPa   900  instant    24   fc  regular_ll
# 688           isobaricInhPa   850  instant    24   fc  regular_ll
# 689           isobaricInhPa   800  instant    24   fc  regular_ll
# 690           isobaricInhPa   750  instant    24   fc  regular_ll
# 691           isobaricInhPa   700  instant    24   fc  regular_ll
# 692           isobaricInhPa   650  instant    24   fc  regular_ll
# 693           isobaricInhPa   600  instant    24   fc  regular_ll
# 694           isobaricInhPa   550  instant    24   fc  regular_ll
# 695           isobaricInhPa   500  instant    24   fc  regular_ll
# 696           isobaricInhPa   450  instant    24   fc  regular_ll
# 697           isobaricInhPa   400  instant    24   fc  regular_ll
# 698           isobaricInhPa   350  instant    24   fc  regular_ll
# 699           isobaricInhPa   300  instant    24   fc  regular_ll
# 700           isobaricInhPa   275  instant    24   fc  regular_ll
# 701           isobaricInhPa   250  instant    24   fc  regular_ll
# 702           isobaricInhPa   225  instant    24   fc  regular_ll
# 703           isobaricInhPa   200  instant    24   fc  regular_ll
# 704           isobaricInhPa   175  instant    24   fc  regular_ll
# 705           isobaricInhPa   150  instant    24   fc  regular_ll
# 706           isobaricInhPa   125  instant    24   fc  regular_ll
# 707           isobaricInhPa   100  instant    24   fc  regular_ll
# 708           isobaricInhPa    70  instant    24   fc  regular_ll
# 709           isobaricInhPa    50  instant    24   fc  regular_ll
# 710           isobaricInhPa    30  instant    24   fc  regular_ll
# 711           isobaricInhPa    20  instant    24   fc  regular_ll
# 712           isobaricInhPa    10  instant    24   fc  regular_ll
# 713           isobaricInhPa  1000  instant    24   fc  regular_ll
# 714           isobaricInhPa   975  instant    24   fc  regular_ll
# 715           isobaricInhPa   950  instant    24   fc  regular_ll
# 716           isobaricInhPa   925  instant    24   fc  regular_ll
# 717           isobaricInhPa   900  instant    24   fc  regular_ll
# 718           isobaricInhPa   850  instant    24   fc  regular_ll
# 719           isobaricInhPa   800  instant    24   fc  regular_ll
# 720           isobaricInhPa   750  instant    24   fc  regular_ll
# 721           isobaricInhPa   700  instant    24   fc  regular_ll
# 722           isobaricInhPa   650  instant    24   fc  regular_ll
# 723           isobaricInhPa   600  instant    24   fc  regular_ll
# 724           isobaricInhPa   550  instant    24   fc  regular_ll
# 725           isobaricInhPa   500  instant    24   fc  regular_ll
# 726           isobaricInhPa   450  instant    24   fc  regular_ll
# 727           isobaricInhPa   400  instant    24   fc  regular_ll
# 728           isobaricInhPa   350  instant    24   fc  regular_ll
# 729           isobaricInhPa   300  instant    24   fc  regular_ll
# 730           isobaricInhPa   275  instant    24   fc  regular_ll
# 731           isobaricInhPa   250  instant    24   fc  regular_ll
# 732           isobaricInhPa   225  instant    24   fc  regular_ll
# 733           isobaricInhPa   200  instant    24   fc  regular_ll
# 734           isobaricInhPa   175  instant    24   fc  regular_ll
# 735           isobaricInhPa   150  instant    24   fc  regular_ll
# 736           isobaricInhPa   125  instant    24   fc  regular_ll
# 737           isobaricInhPa   100  instant    24   fc  regular_ll
# 738           isobaricInhPa    70  instant    24   fc  regular_ll
# 739           isobaricInhPa    50  instant    24   fc  regular_ll
# 740           isobaricInhPa    30  instant    24   fc  regular_ll
# 741           isobaricInhPa    20  instant    24   fc  regular_ll
# 742           isobaricInhPa    10  instant    24   fc  regular_ll
# 743           isobaricInhPa  1000  instant    24   fc  regular_ll
# 744           isobaricInhPa   975  instant    24   fc  regular_ll
# 745           isobaricInhPa   950  instant    24   fc  regular_ll
# 746           isobaricInhPa   925  instant    24   fc  regular_ll
# 747           isobaricInhPa   900  instant    24   fc  regular_ll
# 748           isobaricInhPa   850  instant    24   fc  regular_ll
# 749           isobaricInhPa   800  instant    24   fc  regular_ll
# 750           isobaricInhPa   750  instant    24   fc  regular_ll
# 751           isobaricInhPa   700  instant    24   fc  regular_ll
# 752           isobaricInhPa   650  instant    24   fc  regular_ll
# 753           isobaricInhPa   600  instant    24   fc  regular_ll
# 754           isobaricInhPa   550  instant    24   fc  regular_ll
# 755           isobaricInhPa   500  instant    24   fc  regular_ll
# 756           isobaricInhPa   450  instant    24   fc  regular_ll
# 757           isobaricInhPa   400  instant    24   fc  regular_ll
# 758           isobaricInhPa   350  instant    24   fc  regular_ll
# 759           isobaricInhPa   300  instant    24   fc  regular_ll
# 760           isobaricInhPa   275  instant    24   fc  regular_ll
# 761           isobaricInhPa   250  instant    24   fc  regular_ll
# 762           isobaricInhPa   225  instant    24   fc  regular_ll
# 763           isobaricInhPa   200  instant    24   fc  regular_ll
# 764           isobaricInhPa   175  instant    24   fc  regular_ll
# 765           isobaricInhPa   150  instant    24   fc  regular_ll
# 766           isobaricInhPa   125  instant    24   fc  regular_ll
# 767           isobaricInhPa   100  instant    24   fc  regular_ll
# 768           isobaricInhPa    70  instant    24   fc  regular_ll
# 769           isobaricInhPa    50  instant    24   fc  regular_ll
# 770           isobaricInhPa    30  instant    24   fc  regular_ll
# 771           isobaricInhPa    20  instant    24   fc  regular_ll
# 772           isobaricInhPa    10  instant    24   fc  regular_ll
# 773                 meanSea     0  instant    24   fc  regular_ll
# 774                 surface     0  instant    24   fc  regular_ll
# 775                 surface     0  instant    24   fc  regular_ll
# 776                 surface     0  instant    24   fc  regular_ll
# 777                 surface     0  instant    24   fc  regular_ll
# 778                 surface     0  instant    24   fc  regular_ll
# 779                 surface     0  instant    24   fc  regular_ll
# 780  heightAboveGroundLayer  1000  instant    24   fc  regular_ll
# 781  heightAboveGroundLayer  3000  instant    24   fc  regular_ll
# 782  heightAboveGroundLayer  6000  instant    24   fc  regular_ll
# 783                 surface     0  instant    24   fc  regular_ll
# 784           isobaricInhPa  1000  instant    24   fc  regular_ll
# 785           isobaricInhPa   975  instant    24   fc  regular_ll
# 786           isobaricInhPa   950  instant    24   fc  regular_ll
# 787           isobaricInhPa   925  instant    24   fc  regular_ll
# 788           isobaricInhPa   900  instant    24   fc  regular_ll
# 789           isobaricInhPa   850  instant    24   fc  regular_ll
# 790           isobaricInhPa   800  instant    24   fc  regular_ll
# 791           isobaricInhPa   750  instant    24   fc  regular_ll
# 792           isobaricInhPa   700  instant    24   fc  regular_ll
# 793           isobaricInhPa   650  instant    24   fc  regular_ll
# 794           isobaricInhPa   600  instant    24   fc  regular_ll
# 795           isobaricInhPa   550  instant    24   fc  regular_ll
# 796           isobaricInhPa   500  instant    24   fc  regular_ll
# 797           isobaricInhPa   450  instant    24   fc  regular_ll
# 798           isobaricInhPa   400  instant    24   fc  regular_ll
# 799           isobaricInhPa   350  instant    24   fc  regular_ll
# 800           isobaricInhPa   300  instant    24   fc  regular_ll
# 801           isobaricInhPa   275  instant    24   fc  regular_ll
# 802           isobaricInhPa   250  instant    24   fc  regular_ll
# 803           isobaricInhPa   225  instant    24   fc  regular_ll
# 804           isobaricInhPa   200  instant    24   fc  regular_ll
# 805           isobaricInhPa   175  instant    24   fc  regular_ll
# 806           isobaricInhPa   150  instant    24   fc  regular_ll
# 807           isobaricInhPa   125  instant    24   fc  regular_ll
# 808           isobaricInhPa   100  instant    24   fc  regular_ll
# 809           isobaricInhPa    70  instant    24   fc  regular_ll
# 810           isobaricInhPa    50  instant    24   fc  regular_ll
# 811           isobaricInhPa    30  instant    24   fc  regular_ll
# 812           isobaricInhPa    20  instant    24   fc  regular_ll
# 813           isobaricInhPa    10  instant    24   fc  regular_ll
# 814                 surface     0  instant    24   fc  regular_ll
# 815                 surface     0  instant    24   fc  regular_ll
# 816                 surface     0  instant    24   fc  regular_ll
# 817                 surface     0  instant    24   fc  regular_ll
# 818                 surface     0  instant    24   fc  regular_ll
# 819              atmosphere     0  instant    24   fc  regular_ll
# 820           isobaricInhPa  1000  instant    24   fc  regular_ll
# 821           isobaricInhPa   975  instant    24   fc  regular_ll
# 822           isobaricInhPa   950  instant    24   fc  regular_ll
# 823           isobaricInhPa   925  instant    24   fc  regular_ll
# 824           isobaricInhPa   900  instant    24   fc  regular_ll
# 825           isobaricInhPa   850  instant    24   fc  regular_ll
# 826           isobaricInhPa   800  instant    24   fc  regular_ll
# 827           isobaricInhPa   750  instant    24   fc  regular_ll
# 828           isobaricInhPa   700  instant    24   fc  regular_ll
# 829           isobaricInhPa   650  instant    24   fc  regular_ll
# 830           isobaricInhPa   600  instant    24   fc  regular_ll
# 831           isobaricInhPa   550  instant    24   fc  regular_ll
# 832           isobaricInhPa   500  instant    24   fc  regular_ll
# 833           isobaricInhPa   450  instant    24   fc  regular_ll
# 834           isobaricInhPa   400  instant    24   fc  regular_ll
# 835           isobaricInhPa   350  instant    24   fc  regular_ll
# 836           isobaricInhPa   300  instant    24   fc  regular_ll
# 837           isobaricInhPa   275  instant    24   fc  regular_ll
# 838           isobaricInhPa   250  instant    24   fc  regular_ll
# 839           isobaricInhPa   225  instant    24   fc  regular_ll
# 840           isobaricInhPa   200  instant    24   fc  regular_ll
# 841           isobaricInhPa   175  instant    24   fc  regular_ll
# 842           isobaricInhPa   150  instant    24   fc  regular_ll
# 843           isobaricInhPa   125  instant    24   fc  regular_ll
# 844           isobaricInhPa   100  instant    24   fc  regular_ll
# 845           isobaricInhPa    70  instant    24   fc  regular_ll
# 846           isobaricInhPa    50  instant    24   fc  regular_ll
# 847           isobaricInhPa    30  instant    24   fc  regular_ll
# 848           isobaricInhPa    20  instant    24   fc  regular_ll
# 849           isobaricInhPa    10  instant    24   fc  regular_ll
# 850                 surface     0  instant    24   fc  regular_ll
# 851                 surface     0  instant    24   fc  regular_ll
# 852                 surface     0  instant    24   fc  regular_ll
# 853                 surface     0  instant    24   fc  regular_ll
# 854       heightAboveGround    10  instant    24   fc  regular_ll
# 855                 surface     0  instant    24   fc  regular_ll
# 856                 surface     0  instant    24   fc  regular_ll
# 857                 surface     0  instant    24   fc  regular_ll
# 858                 surface     0  instant    24   fc  regular_ll
# 859                 surface     0  instant    24   fc  regular_ll
# 860                 surface     0  instant    24   fc  regular_ll
