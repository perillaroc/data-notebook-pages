# %% [markdown]
# # REPS要素清单：59-71

# %%
import numpy as np
import pandas as pd
import xarray as xr

from reki.format.grib.eccodes import load_field_from_file
# Out:
# /home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/.venv/lib/python3.14/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.42.0 or higher is recommended. You are running version 2.34.1
#   warnings.warn(

# %%
from data_notebook.data import get_data_file

reps_grib2_orig_file_path = get_data_file("cma-reps")
reps_grib2_orig_file_path
# Out:
# PosixPath('/home/wangdp/project/cedarkit/notebook-project/notebook-devel/ref/data-notebook-project/data-notebook/data/cma-reps/grib2/orig/Z_NAFP_C_BABJ_20260811060000_P_NWPC-GRAPES-REPS-CN-02400-m001.grib2')

# %% [markdown]
# ## 稳定度指数

# %% [markdown]
# ### 2米相对湿度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 59 | rh2m | RH | 2r | (0, 1, 1) | % | heightAboveGround | 2 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="RH",
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 59

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="2r",
    lazy=True
)
assert field.attrs["GRIB_count"] == 59

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="rh2m",
    lazy=True
)
assert field.attrs["GRIB_count"] == 59

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 1},
    level_type="heightAboveGround",
    level=2,
    lazy=True
)
assert field.attrs["GRIB_count"] == 59

# %% [markdown]
# ### K指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 60 | kidx | KX | kx | (0, 7, 2) | C | meanSea | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="KX",
    lazy=True
)
assert field.attrs["GRIB_count"] == 60

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="kx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 60

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="kidx",
    lazy=True
)
assert field.attrs["GRIB_count"] == 60

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 2},
    lazy=True
)
assert field.attrs["GRIB_count"] == 60

# %% [markdown]
# ### 对流有效位能

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 61 | cape | CAPE | — | (0, 7, 6) | J/kg | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="CAPE",
    lazy=True
)
assert field.attrs["GRIB_count"] == 61

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="cape",
    lazy=True
)
assert field.attrs["GRIB_count"] == 61

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 6},
    lazy=True
)
assert field.attrs["GRIB_count"] == 61

# %% [markdown]
# ### 对流抑制能量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 62 | cin | CIN | — | (0, 7, 7) | J/kg | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="CIN",
    lazy=True
)
assert field.attrs["GRIB_count"] == 62

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="cin",
    lazy=True
)
assert field.attrs["GRIB_count"] == 62

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 7},
    lazy=True
)
assert field.attrs["GRIB_count"] == 62

# %% [markdown]
# ### 下沉对流有效位能

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 63 | dcape | DCAPE | — | (0, 7, 224) | J/kg | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="DCAPE",
    lazy=True
)
assert field.attrs["GRIB_count"] == 63

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="dcape",
    lazy=True
)
assert field.attrs["GRIB_count"] == 63

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 224},
    lazy=True
)
assert field.attrs["GRIB_count"] == 63

# %% [markdown]
# ### 0-1000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 64 | shr(0-1000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 1000 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VWSH",
    lazy=True
)
assert field.attrs["GRIB_count"] == 64

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="vwsh",
    lazy=True
)
assert field.attrs["GRIB_count"] == 64

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="shr(0-1000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 64

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 25},
    lazy=True
)
assert field.attrs["GRIB_count"] == 64

# %% [markdown]
# ### 0-3000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 65 | shr(0-3000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 3000 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VWSH",
    level_type="heightAboveGroundLayer",
    level=3000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 65

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="vwsh",
    level_type="heightAboveGroundLayer",
    level=3000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 65

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="shr(0-3000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 65

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 25},
    level_type="heightAboveGroundLayer",
    level=3000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 65

# %% [markdown]
# ### 0-6000米垂直风切变

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 66 | shr(0-6000) | VWSH | vwsh | (0, 2, 25) | s-1 | heightAboveGroundLayer | 6000 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VWSH",
    level_type="heightAboveGroundLayer",
    level=6000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 66

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="vwsh",
    level_type="heightAboveGroundLayer",
    level=6000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 66

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="shr(0-6000)",
    lazy=True
)
assert field.attrs["GRIB_count"] == 66

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 25},
    level_type="heightAboveGroundLayer",
    level=6000,
    lazy=True
)
assert field.attrs["GRIB_count"] == 66

# %% [markdown]
# ### 最优抬升指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 67 | bli | BLI | bli | (0, 7, 1) | K | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="BLI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 67

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="bli",
    lazy=True
)
assert field.attrs["GRIB_count"] == 67

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 7, "parameterNumber": 1},
    lazy=True
)
assert field.attrs["GRIB_count"] == 67

# %% [markdown]
# ### 炎热指数

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 68 | hi | HI | — | (0, 1, 239) | — | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="HI",
    lazy=True
)
assert field.attrs["GRIB_count"] == 68

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="hi",
    lazy=True
)
assert field.attrs["GRIB_count"] == 68

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 239},
    lazy=True
)
assert field.attrs["GRIB_count"] == 68

# %% [markdown]
# ### 整层可降水量

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 69 | pwat | PWAT | pwat | (0, 1, 3) | kg/kg | atmosphere | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="PWAT",
    lazy=True
)
assert field.attrs["GRIB_count"] == 69

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="pwat",
    lazy=True
)
assert field.attrs["GRIB_count"] == 69

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 1, "parameterNumber": 3},
    lazy=True
)
assert field.attrs["GRIB_count"] == 69

# %% [markdown]
# ## 能见度与阵风

# %% [markdown]
# ### 能见度

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 70 | vis | VIS | vis | (0, 19, 0) | m | surface | 0 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="VIS",
    lazy=True
)
assert field.attrs["GRIB_count"] == 70

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="vis",
    lazy=True
)
assert field.attrs["GRIB_count"] == 70

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 19, "parameterNumber": 0},
    lazy=True
)
assert field.attrs["GRIB_count"] == 70

# %% [markdown]
# ### 阵风风速

# %% [markdown]
# | 序号 | 要素名 | wgrib2 | eccodes | GRIB key | 单位 | 层次类型 | 层次 | 统计类型 | 时效 | 数据类型 | 网格类型 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | 71 | gust | GUST | i10fg | (0, 2, 22) | m/s | heightAboveGround | 10 | instant | 24 | pf | regular_ll |

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="GUST",
    lazy=True
)
assert field.attrs["GRIB_count"] == 71

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="i10fg",
    lazy=True
)
assert field.attrs["GRIB_count"] == 71

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter="gust",
    lazy=True
)
assert field.attrs["GRIB_count"] == 71

# %%
field = load_field_from_file(
    reps_grib2_orig_file_path,
    parameter={"discipline": 0, "parameterCategory": 2, "parameterNumber": 22},
    lazy=True
)
assert field.attrs["GRIB_count"] == 71
